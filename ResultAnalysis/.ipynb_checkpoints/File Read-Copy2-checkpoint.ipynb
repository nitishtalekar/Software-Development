# %%
#LIBRARIES
import pandas as pd
import matplotlib.pyplot as plt

# %%
#READ FILE + DROP NULL COLUMNS
original_file = pd.read_excel('Check.xlsx')
original_file.dropna(how="all", inplace=True)
original_file = original_file.drop(['Unnamed: 1','Unnamed: 28','Unnamed: 29'], axis=1)
# original_file.dropna(axis='columns', how='all')

# %%
df = original_file.iloc[3:,:]

# %%
df.columns = original_file.iloc[2,:]
df
# Out:
# 7                                              NaN  \
# 8                      Seat No / Name of Student ↓
# 9                                              NaN
# 10                                             NaN
# 11                                           16001
# 12                  ADE VIKAS ROHIDAS KAUSHALYABAI
# 13                                           16002
# 14                   ADGA GAURAV SHASHANK HEMALATA
# 15                                           16003
# 16                       AGAWANE ROHIT ARJUN LAXMI
# 17                                           16004
# 18                    AHIRE KSHITIJ MAHENDRA LEENA
# 19                                           16005
# 20              AMBERKAR AASHUTOSH DIVAKAR HEMANGI
# 21                                           16006
# 22                ANAS DANISH FAIZIRAB NISHATANJUM
# 23                                           16007
# 24     ANSARI ARAFAT AHMAD NASEEM PARVEZ SAIRABANO
# 25                                           16008
# 26   ARORA KARAN SINGH JITENDARSINGH ARVINDER KAUR
# 27                                           16009
# 28          ASOLKAR PRATHAMESH PARSHURAM PADMAVATI
# 29                                           16010
# 30                       AYARE MANAS RAMESH MANASI
# 31                                           16011
# 32               BABANI JITESHKUMAR MANOHAR BABITA
# 33                                           16012
# 34                      BAGADE SAURABH GAUTAM USHA
# 35                                           16013
# 36                BAGDE SHUBHAM BALKRISHNA MANISHA
# 37                                           16014
# ..                                             ...
# 312                         MARCHANDE SAGAR SANJAY
# 313                                          16152
# 314                           MATHKAR SUYASH MOHAN
# 315                                          16153
# 316                     PARKAR WASEEM DAUD RUKSANA
# 317                                          16154
# 318                         PATOLE PRANAV RAJENDRA
# 319                                          16155
# 320        PATTANAIK ANUVEDYA BIJAY BHUSAN INDRANI
# 321                                          16156
# 322          PETHANI HARDIK JAYSUKHBHAI MANJULABEN
# 323                                          16157
# 324                     RAO PRASHIN PRASANNA NAINA
# 325                                          16158
# 326                      SAHNI SUMEET SUSHIL SONIA
# 327                                          16159
# 328                         SARFARE YASH ARUN ARTI
# 329                                          16160
# 330                 SAYARE SURAJ KAMALAKAR KANCHAN
# 331                                          16161
# 332                        SHAH JINAY NEETIN HEENA
# 333                                          16162
# 334                             VAITY AAYUSH VIJAY
# 335                                          16163
# 336                     VORA ATMAN MAHENDRA BHADRA
# 337                                          16164
# 338            YADAV DEEPAKKUMAR DINESHSINGH SUMAN
# 339                                          16165
# 340                           BHISE AKSHAY HARSHAD
# 343                                            NaN
#
# 7   METROLOGY AND QUALITY ENGINEERING  NaN  NaN    NaN  NaN  NaN  \
# 8                                ESE   IA   TOT  PR OR   TW  TOT
# 9                                  80   20  100     25   25   50
# 10                                 32    8   40     10   10   20
# 11                                41E  19E   60    19E  18E   37
# 12                                  D    O    C      A    B    B
# 13                                 53   18   71     20   19   39
# 14                                  C    O    B      O    A    A
# 15                                 54   18   72     21   19   40
# 16                                  C    O    B      O    A    O
# 17                                 57   18   75     20   19   39
# 18                                  B    O    A      O    A    A
# 19                                 41   16   57     18   18   36
# 20                                  D    O    D      B    B    B
# 21                                 40   16   56     19   20   39
# 22                                  D    O    D      A    O    A
# 23                                 46   15   61     20   18   38
# 24                                  D    A    C      O    B    A
# 25                                34E  16E   50    17E  17E   34
# 26                                  P    O    D      C    C    C
# 27                                 49   12   61     16   17   33
# 28                                  C    C    C      C    C    C
# 29                                39E  15E   54    17E  14E   31
# 30                                  E    A    D      C    D    C
# 31                                 45   17   62     17   14   31
# 32                                  D    O    C      C    D    C
# 33                                44E  17E   61    18E  19E   37
# 34                                  D    O    C      B    A    B
# 35                                 52   19   71     18   16   34
# 36                                  C    O    B      B    C    C
# 37                                 54   19   73     21   20   41
# ..                                ...  ...  ...    ...  ...  ...
# 312                                 D    C    D      B    A    B
# 313                               34+  09+   43    15+  10+   25
# 314                                 P    E    P      C    P    D
# 315                               32+  08+   40    17+  17+   34
# 316                                 P    P    P      C    C    C
# 317                               48+  11+   59    16+  17+   33
# 318                                 C    D    D      C    C    C
# 319                               32+  08+   40    12+  10+   22
# 320                                 P    P    P      E    P    P
# 321                               32+  12+   44    15+  17+   32
# 322                                 P    C    P      C    C    C
# 323                               32+  09+   41    19+  18+   37
# 324                                 P    E    P      A    B    B
# 325                               40+  10+   50    17+  17+   34
# 326                                 D    D    D      C    C    C
# 327                               39+  11+   50    16+  18+   34
# 328                                 E    D    D      C    B    C
# 329                               32+  10+   42    20+  18+   38
# 330                                 P    D    P      O    B    A
# 331                               32+  08+   40    15+  19+   34
# 332                                 P    P    P      C    A    C
# 333                               46+  11+   57    18+  17+   35
# 334                                 D    D    D      B    C    B
# 335                               36+  09+   45    16+  10+   26
# 336                                 E    E    E      C    P    D
# 337                               32+  13+   45    20+  14+   34
# 338                                 P    C    E      O    D    C
# 339                               32+  10+   42    17+  15+   32
# 340                                 P    D    P      C    C    C
# 343                               NaN  NaN  NaN    NaN  NaN  NaN
#
# 7   MACHINE DESIGN I  NaN  NaN  ...  NaN FINITE ELEMENT ANALYSIS  NaN  NaN  \
# 8               ESE   IA   TOT  ...   TW                    ESE   IA    TW
# 9                 80   20  100  ...   25                      80   20   25
# 10                32    8   40  ...   10                      32    8   10
# 11               38E  09E   47  ...  12E                     22F  17E  15E
# 12                 E    E    E  ...    E                       F    O    C
# 13                51   09   60  ...   20                      37   20   20
# 14                 C    E    C  ...    O                       E    O    O
# 15                53   13   66  ...   19                      32   18   19
# 16                 C    C    C  ...    A                       P    O    A
# 17                54   09   63  ...   19                      37   17   19
# 18                 C    E    C  ...    A                       E    O    A
# 19                40   12   52  ...   20                      32   14   18
# 20                 D    C    D  ...    O                       P    B    B
# 21                45   10   55  ...   16                      36   16   18
# 22                 D    D    D  ...    C                       E    O    B
# 23                47   11   58  ...   18                      44   17   16
# 24                 D    D    D  ...    B                       D    O    C
# 25               32E  10E   42  ...  18E                     19F  14E  16E
# 26                 P    D    P  ...    B                       F    B    C
# 27                50   11   61  ...   20                      33   17   19
# 28                 C    D    C  ...    O                       P    O    A
# 29               32E  09E   41  ...  10E                     20F  12E  14E
# 30                 P    E    P  ...    P                       F    C    D
# 31                50   12   62  ...   12                      32   15   17
# 32                 C    C    C  ...    E                       P    A    C
# 33               54E  09E   63  ...  19E                     14F  16E  20E
# 34                 C    E    C  ...    A                       F    O    O
# 35                54   09   63  ...   14                      33   19   17
# 36                 C    E    C  ...    D                       P    O    C
# 37                61   10   71  ...   21                      53   20   17
# ..               ...  ...  ...  ...  ...                     ...  ...  ...
# 312                E    E    E  ...    C                       P    C    O
# 313              38E   Ab   38  ...  15+                     32+  10+  11+
# 314                E    F    F  ...    C                       P    D    P
# 315              32+  09+   41  ...  14+                     32+  09+  22+
# 316                P    E    P  ...    D                       P    E    O
# 317              33+  09+   42  ...  15+                     32+  11+  17+
# 318                P    E    P  ...    C                       P    D    C
# 319              33+  08+   41  ...  11+                     32+  09+  12+
# 320                P    P    P  ...    P                       P    E    E
# 321              32+  09E   41  ...  13+                     36+  10+  15+
# 322                P    E    P  ...    D                       E    D    C
# 323              37+  08+   45  ...  19+                     32+  14+  20+
# 324                E    P    E  ...    A                       P    B    O
# 325              38+  08+   46  ...  12+                     40+  13+  15+
# 326                E    P    E  ...    E                       D    C    C
# 327              32+  08+   40  ...  16+                     21F  11+  20+
# 328                P    P    P  ...    C                       F    D    O
# 329              34+  09+   43  ...  12+                     32+  09+  23+
# 330                P    E    P  ...    E                       P    E    O
# 331              32+  08+   40  ...  14+                     32E  11+  17+
# 332                P    P    P  ...    D                       P    D    C
# 333               42  10+   52  ...  14+                      39  09+  20+
# 334                D    D    D  ...    D                       E    E    O
# 335              34+   Ab   34  ...  10+                     32+  14+  11+
# 336                P    F    F  ...    P                       P    B    P
# 337              08F  08+   16  ...  12+                     32+  10+  22+
# 338                F    P    F  ...    E                       P    D    O
# 339              32+  09+   41  ...  14+                     32+  09+  21+
# 340                P    E    P  ...    D                       P    E    O
# 343              NaN  NaN  NaN  ...  NaN                     NaN  NaN  NaN
#
# 7    NaN  NaN   NaN  NaN   NaN      NaN
# 8    TOT  NaN   NaN  NaN   NaN      NaN
# 9     50  825   NaN  NaN   NaN      NaN
# 10    20  NaN   NaN  NaN   NaN      NaN
# 11    31  455   5.5    F  3.19      NaN
# 12     C  NaN   NaN  NaN   NaN      NaN
# 13    40  558  7.79    P  5.84      NaN
# 14     O  NaN   NaN  NaN   NaN      NaN
# 15    40  548  7.57    P   5.5      NaN
# 16     O  NaN   NaN  NaN   NaN      NaN
# 17    40  538  7.29    P  5.43      NaN
# 18     O  NaN   NaN  NaN   NaN      NaN
# 19    36  504  6.71    P  5.57      NaN
# 20     B  NaN   NaN  NaN   NaN      NaN
# 21    37  531  7.04    P   5.8      NaN
# 22     B  NaN   NaN  NaN   NaN      NaN
# 23    32  510  6.75    P  4.68      NaN
# 24     C  NaN   NaN  NaN   NaN      NaN
# 25    33  433  5.04    F  4.33      NaN
# 26     C  NaN   NaN  NaN   NaN      NaN
# 27    37  521  7.21    P  5.41      NaN
# 28     B  NaN   NaN  NaN   NaN      NaN
# 29    27  399  4.07    F   3.5      NaN
# 30     D  NaN   NaN  NaN   NaN      NaN
# 31    37  478  6.11    P  3.39      NaN
# 32     B  NaN   NaN  NaN   NaN      NaN
# 33    40  514  6.71    F  6.35      NaN
# 34     O  NaN   NaN  NaN   NaN      NaN
# 35    35  541  7.32    P  7.54      NaN
# 36     B  NaN   NaN  NaN   NaN      NaN
# 37    36  634     9    P  6.86      NaN
# ..   ...  ...   ...  ...   ...      ...
# 312    A  NaN   NaN  NaN   NaN      NaN
# 313   22  378  4.18    F  3.71      NaN
# 314    P  NaN   NaN  NaN   NaN      NaN
# 315   36  415  5.11    P  4.95      NaN
# 316    B  NaN   NaN  NaN   NaN      NaN
# 317   33  424  5.04    P  2.81      NaN
# 318    C  NaN   NaN  NaN   NaN      NaN
# 319   24  340  3.54    F  3.24      NaN
# 320    E  NaN   NaN  NaN   NaN      NaN
# 321   29  365  4.14    F   1.6      NaN
# 322    D  NaN   NaN  NaN   NaN      NaN
# 323   39  440  5.71    P  3.65  RS1,RS2
# 324    A  NaN   NaN  NaN   NaN      NaN
# 325   29  409  5.04    P  4.08      NaN
# 326    D  NaN   NaN  NaN   NaN      NaN
# 327   38  406  4.71    F  5.75      NaN
# 328    A  NaN   NaN  NaN   NaN      NaN
# 329   44  392  4.18    F  3.79      NaN
# 330    O  NaN   NaN  NaN   NaN      NaN
# 331   32  386  4.07    F  2.45      NaN
# 332    C  NaN   NaN  NaN   NaN      NaN
# 333   38  438  5.39    P  5.32      NaN
# 334    A  NaN   NaN  NaN   NaN      NaN
# 335   22  289  2.86    F  1.88      NaN
# 336    P  NaN   NaN  NaN   NaN      NaN
# 337   37  352  3.46    F  4.04      NaN
# 338    B  NaN   NaN  NaN   NaN      NaN
# 339   41  419  5.04    P  2.46      NaN
# 340    O  NaN   NaN  NaN   NaN      NaN
# 343    0  NaN   NaN  NaN   NaN      NaN
#
# [334 rows x 34 columns]

# %%
#HEADER LIST
colog = list(df.columns.values)
col = [str(i) for i in list(df.columns.values)]
c = col[:]
unclean_column_names = col.copy()
col2 = df.iloc[:1,:].values[0]

for i in col:
    if col.count(i) == 2:
        col[col.index(i)] = i+'-T'
        
i=2
while i < len(col):
    x = col[i-1]
    while 'nan' in col[i]:
        col[i] = x
        i = i+1
    i = i+1



    
    
    
#INITIALIZE
col[0] = 'SEAT NUM'
col.append('TOTAL')
col.append('GPA')
col.append('RESULT')
col2[0] = ''
col2[-1] = ''
col2[-2] = ''
col2[-3] = ''

# print(l)
cols = list(zip(col,col2))
header = ["-".join(i).strip('-') for i in cols]

col.insert(1,'NAME')  #For Storing orignal order of columns
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-28d7b254c49f> in <module>
#      13 while i < len(col):
#      14     x = col[i-1]
# ---> 15     while 'nan' in col[i]:
#      16         col[i] = x
#      17         i = i+1
#
# IndexError: list index out of range

# %%
col
# Out:
# ['nan',
#  'METROLOGY AND QUALITY ENGINEERING',
#  'METROLOGY AND QUALITY ENGINEERING',
#  'METROLOGY AND QUALITY ENGINEERING',
#  'METROLOGY AND QUALITY ENGINEERING',
#  'METROLOGY AND QUALITY ENGINEERING',
#  'METROLOGY AND QUALITY ENGINEERING',
#  'MACHINE DESIGN I',
#  'MACHINE DESIGN I',
#  'MACHINE DESIGN I',
#  'MACHINE DESIGN I',
#  'MECHANICAL VIBRATIONS',
#  'MECHANICAL VIBRATIONS',
#  'MECHANICAL VIBRATIONS',
#  'MECHANICAL VIBRATIONS',
#  'MECHANICAL VIBRATIONS',
#  'MECHANICAL VIBRATIONS',
#  'THERMAL AND FLUID POWER ENGINEERING',
#  'THERMAL AND FLUID POWER ENGINEERING',
#  'THERMAL AND FLUID POWER ENGINEERING',
#  'THERMAL AND FLUID POWER ENGINEERING',
#  'MECHATRONICS ',
#  'MECHATRONICS ',
#  'MECHATRONICS ',
#  'MECHATRONICS ',
#  'FINITE ELEMENT ANALYSIS',
#  'FINITE ELEMENT ANALYSIS',
#  'FINITE ELEMENT ANALYSIS',
#  'FINITE ELEMENT ANALYSIS',
#  'FINITE ELEMENT ANALYSIS',
#  'FINITE ELEMENT ANALYSIS',
#  'FINITE ELEMENT ANALYSIS',
#  'FINITE ELEMENT ANALYSIS',
#  'FINITE ELEMENT ANALYSIS']

# %%
newdf = df.iloc[2:,:]
newdf.columns = original_file.iloc[1,:]
coursenum = [str(i) for i in list(newdf.columns)][1:-3]
coursenum = [i for i in coursenum if 'nan' not in i]
subject_names = [i for i in unclean_column_names if 'nan' not in i]
subjectcodes = dict(zip(coursenum,subject_names))

# %%
df.columns = header
df = df.iloc[3:,:]
df.index = pd.RangeIndex(len(df.index))

dfmarks = df.loc[::2]
dfnames = df.loc[1::2]

# dfmarks.loc[:,'NAME'] = dfnames['SEAT NUM'].values
dfmarks.loc[:,'NAME'] = dfnames.loc[:,'SEAT NUM'].values
dfmarks.index = pd.RangeIndex(len(dfmarks.index))

# %%
l = [i for i in dfnames.columns if 'TOT' in i][:-1] + list(dfnames.columns[-3:])
dfnames = dfnames.drop(l, axis=1)

# %%
dfmarks['STRENGTH OF MATERIALS-TOT'].apply(clean)
# Out:
# 0      37
# 1      33
# 2      35
# 3      33
# 4      37
# 5      47
# 6      41
# 7      41
# 8      40
# 9      38
# 10     37
# 11     45
# 12     45
# 13     32
# 14     45
# 15     38
# 16     36
# 17     41
# 18     38
# 19     41
# 20     24
# 21     24
# 22     37
# 23     43
# 24     41
# 25     38
# 26     41
# 27     32
# 28     33
# 29     39
#        ..
# 103    40
# 104    37
# 105    Ab
# 106    34
# 107    32
# 108    41
# 109    41
# 110    46
# 111    31
# 112    37
# 113    45
# 114    40
# 115    47
# 116    40
# 117    44
# 118    41
# 119    43
# 120    39
# 121    38
# 122    38
# 123    42
# 124    42
# 125    45
# 126    38
# 127    38
# 128    41
# 129    37
# 130    37
# 131    33
# 132    48
# Name: STRENGTH OF MATERIALS-TOT, Length: 133, dtype: object

# %%
def clean(x):
#     if x == 'Ab':
#         return int(0)
    x = list(str(x))
    if x[-1] == 'E' or  x[-1] == 'F':
        return "".join(x[:-1]).strip()
    else:
        return "".join(x)

# %%
for i in dfmarks.columns[1:-4]:
    dfmarks.loc[:,i] = dfmarks.loc[:,i].apply(clean)
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
dfcolumns = list(dfmarks.columns)
totalcols = [dfcolumns[0]] + [i for i in dfcolumns if 'TOT' in i]
totalcols = totalcols + dfcolumns[-3:]
dftotalmarks = dfmarks.loc[:,totalcols]

# %%
originalcol = col[:]
originalcol = list( dict.fromkeys(originalcol) ) #Stores Original Order of columns

# %%
#REORDER COLUMNS
totalmarkscol = []
for i in originalcol:
    if i in dftotalmarks.columns:
        totalmarkscol.append(i)
    elif str(i+str('-TOT')) in dftotalmarks.columns:
        totalmarkscol.append(str(i+str('-TOT')))

# %%
temp = [i for i in coursenum if coursenum[0][:3] in i]

# %%
subjectcols = list(dftotalmarks)[2:-3]
subjectcols = subjectcols[:len(temp)]

# %%
subjectcols
# Out:
# ['THERMODYNAMICS-TOT',
#  'STRENGTH OF MATERIALS-T-TOT',
#  'PRODUCTION PROCESS I-TOT',
#  'MATERIAL TECHNOLOGY-T-TOT',
#  'COMPUTER AIDED MACHINE DRAWING -TOT']

# %%
totalmarkscol = totalmarkscol[:2] + subjectcols + totalmarkscol[-3:]
totalmarkscol
# Out:
# ['SEAT NUM',
#  'NAME',
#  'THERMODYNAMICS-TOT',
#  'STRENGTH OF MATERIALS-T-TOT',
#  'PRODUCTION PROCESS I-TOT',
#  'MATERIAL TECHNOLOGY-T-TOT',
#  'COMPUTER AIDED MACHINE DRAWING -TOT',
#  'TOTAL',
#  'GPA',
#  'RESULT']

# %%
dftotalmarks = dftotalmarks[totalmarkscol]
dftotalmarks
# Out:
#     SEAT NUM                                        NAME THERMODYNAMICS-TOT  \
# 0      13001                         ABHIJITH SHAH  NITA                 24
# 1      13002            AGRAWAL AKHILESH SANJAY ANURADHA                 30
# 2      13003                   AGRAWAL RONAK ANIL VARSHA                 53
# 3      13004            ALDAR ROHAN PANDHARINATH SANGITA                 30
# 4      13005               AWATE TEJAS PANDURANG RANJANA                 18
# 5      13006               BHALERAO ASHUTOSH VIJAY AARTI                 54
# 6      13007               / BHARAMBE DAMINI NITIN JYOTI                 84
# 7      13008                 BHOIR CHIRAG PRADEEP PRACHI                 58
# 8      13009                     BHURKE SOHAM NITIN NEHA                 45
# 9      13010                 BOKKA HARISH TATARAO KUSUMA                 58
# 10     13011         BORHADE SHUBHAM GORAKHNATH VAISHALI                 30
# 11     13012         CHACHARE AKSHAY DNYANESHWAR VANDANA                 56
# 12     13013              CHAUHAN RAHUL RAMKUMAR SUMITRA                 50
# 13     13014             / CHAVAN SHREYA TUSHAR PRATIBHA                 43
# 14     13015                CHOWTA PAWAN NAGESH SHARMILA                 78
# 15     13016                  DAGALE AKASH KALU LAXMIBAI                 29
# 16     13017               / DAMANKAR SAKSHI UDAY SHWETA                 28
# 17     13018            / DAMRE SHWETA GANGARAM JAYSHREE                 45
# 18     13019                  DAVANDE TEJAS VIJAY SHWETA                 51
# 19     13020         / DEVARE JAGRUTI YOGESH PUSHPANJALI                 47
# 20     13021              DHOLE SHRIKANT VIKASRAO CHHAYA                 27
# 21     13022             DHUM JAGDISH SANDESH BHAGYASHRI                  3
# 22     13023  FURNITUREWALA ABBAS ALI RAZA RASHID MAHEEN                 45
# 23     13024                 GHADGE ATUL SAMBHAJI MANGAL                 44
# 24     13025                 GHALOT AYUR JITENDRA KARUNA                 45
# 25     13026            / GHATKAR TEJASHREE SUNIL RUPALI                 22
# 26     13027                   / GHOLAP ARATI VIJAY LATA                 27
# 27     13028                GODE NIKHIL RANGNATH PALLAVI                 25
# 28     13029     GOSAVI KALPESH DNYANESHWAR DNYANESHWARI                 50
# 29     13030                  GUPTE SOMIL SANJAY SUMEDHA                 49
# ..       ...                                         ...                ...
# 103    13105                SANKHE HIMANK SANTOSH DAKSHA                 44
# 104    13106              / SANKHE SAYLI SURESH SUCHITRA                 58
# 105    13107                 SAPARIYA HARDIK ASHOK NISHA                 Ab
# 106    13108             SAWANT AMEYA NANDAKUMAR NAMRATA                 42
# 107    13109              SAYYED SAIFULLAH IRFAN SALWANA                 30
# 108    13110                  SHAIKH AKIF JAKIR KHURSHID                 54
# 109    13111           SHARMA DURGESH KUMAR GANESH LEELA                 55
# 110    13112              / SHARMA PRERNA YOGENDRA MEENU                 56
# 111    13113                    SHARMA SAHIL SUNIL SWETA                 23
# 112    13114    SHARMA YOGESH KOUSHAL RAJESH KUMAR SHUBH                 49
# 113    13115              SHEDAGE AMIT RAVINDRA VAISHALI                 61
# 114    13116                SHELKE AKASH PRAKASH SUSHAMA                 56
# 115    13117             SHINDE ADARSH ANILKUMAR ASHWINI                 58
# 116    13118                  SHINDE AKSHAY SUNIL AARATI                 46
# 117    13119                SHINDE NIKHIL RAJENDRA ANITA                 70
# 118    13120       SINGH ANUP SHATRUJEETSINGH REETASINGH                 67
# 119    13121                SUTAR NISHANT ASHOK VAISHALI                 70
# 120    13122            SUVARNA AAKASH LEELADHAR SUREKHA                 52
# 121    13123         / TAMBADKAR KSHITIJA PRAKASH RAKSHA                 31
# 122    13124             / THAKUR UTKARSHA SANJAY NILIMA                 44
# 123    13125               TODANKAR SWARAJ VIKAS VISHAYA                 65
# 124    13126                     TOMAR ABHIJEET D SUNITA                 56
# 125    13127             UBALE KAUSTUBH HARILAL HARSHADA                 64
# 126    13128               VANJARE SIDDHESH VISHNU VEENA                 13
# 127    13129           VENGURLEKAR PRASAD SHRIDHAR SEEMA                 58
# 128    13130               VHAVALE PANKAJ SANJAY MANISHA                 54
# 129    13131                   WAGH KAMLESH ARUN SUREKHA                 25
# 130    13132                  / WANI PRIYANKA BIJU NISHA                 41
# 131    13133            YADAV PRATHMESH BHUPESH VAISHALI                 25
# 132    13134                 YEOLA SAURABH SUNIL VANDANA                 67
#
#     STRENGTH OF MATERIALS-T-TOT PRODUCTION PROCESS I-TOT  \
# 0                            30                       57
# 1                            50                       57
# 2                            76                       68
# 3                            46                       43
# 4                            30                       58
# 5                            68                       83
# 6                            78                       72
# 7                            76                       56
# 8                            82                       46
# 9                            61                       59
# 10                           53                       58
# 11                           48                       77
# 12                           85                       49
# 13                           64                       41
# 14                           90                       79
# 15                           44                       54
# 16                           28                       46
# 17                           34                       75
# 18                           78                       60
# 19                           55                       68
# 20                           12                        4
# 21                            2                        5
# 22                           44                       54
# 23                           79                       41
# 24                           44                       60
# 25                           22                       27
# 26                           42                       66
# 27                           35                       43
# 28                           71                       58
# 29                           55                       53
# ..                          ...                      ...
# 103                          46                       59
# 104                          56                       52
# 105                          Ab                        0
# 106                          14                       41
# 107                          41                       20
# 108                          49                       41
# 109                          56                       65
# 110                          86                       71
# 111                          40                       26
# 112                          40                       42
# 113                          77                       57
# 114                          75                       75
# 115                          65                       74
# 116                          58                       53
# 117                          74                       55
# 118                          67                       61
# 119                          72                       61
# 120                          56                       53
# 121                          44                       49
# 122                          28                       43
# 123                          65                       74
# 124                          70                       55
# 125                          78                       67
# 126                          29                       43
# 127                          41                       49
# 128                          57                       52
# 129                          21                       44
# 130                          40                       44
# 131                          39                       32
# 132                          70                       75
#
#     MATERIAL TECHNOLOGY-T-TOT COMPUTER AIDED MACHINE DRAWING -TOT TOTAL   GPA  \
# 0                          47                                  56   344  2.96
# 1                          51                                  49   366  3.69
# 2                          64                                  62   471  7.23
# 3                          42                                  54   333  3.12
# 4                          44                                  81   323  3.65
# 5                          71                                  86   517  7.92
# 6                          78                                  88   584  9.35
# 7                          66                                  79   521  8.08
# 8                          59                                  80   477  7.46
# 9                          62                                  77   492  7.69
# 10                         44                                  75   433  6.08
# 11                         77                                  90   516  7.85
# 12                         76                                  91   538  8.42
# 13                         51                                  60   402  6.04
# 14                         84                                  68   608  9.35
# 15                         59                                  76   384  4.69
# 16                         47                                  84   358  3.88
# 17                         60                                  74   430   NaN
# 18                         64                                  89   518  8.15
# 19                         69                                  75   470  7.08
# 20                          3                                  30   153     1
# 21                          4                                  31   120  1.04
# 22                         49                                  72   433   6.5
# 23                         51                                  54   438  6.62
# 24                         61                                  83   446  6.88
# 25                         23                                  52   271  2.15
# 26                         26                                  80   366  4.38
# 27                         29                                  60   319  3.27
# 28                         58                                  73   477  7.42
# 29                         64                                  53   439  6.54
# ..                        ...                                 ...   ...   ...
# 103                        51                                  89   457  6.77
# 104                        60                                  78   451  6.81
# 105                         3                                  Ab    17   NaN
# 106                        42                                  65   319  3.77
# 107                        29                                  70   326  3.62
# 108                        44                                  66   408  5.92
# 109                        71                                  91   513  7.77
# 110                        67                                  89   545  8.19
# 111                        40                                  38   277  2.15
# 112                        64                                  90   426  6.04
# 113                        72                                  74   533  8.23
# 114                        72                                  82   539  8.73
# 115                        64                                  90   525  7.77
# 116                        22                                  60   391  5.88
# 117                        56                                  96   539  8.23
# 118                        65                                  70   488  7.42
# 119                        64                                  84   529  8.31
# 120                        65                                  76   458     7
# 121                        53                                  66   395  5.12
# 122                        41                                  71   363  4.04
# 123                        76                                  90   531  8.12
# 124                        67                                  85   519  8.12
# 125                        57                                  83   525  8.15
# 126                        38                                  76   318  3.08
# 127                        62                                  80   433   6.5
# 128                        55                                  54   432  6.65
# 129                        31                                  75   334  3.12
# 130                        45                                  63   364  5.23
# 131                        37                                  61   324  2.73
# 132                        62                                  82   550  8.73
#
#     RESULT
# 0        F
# 1        F
# 2        P
# 3        F
# 4        F
# 5        P
# 6        P
# 7        P
# 8        P
# 9        P
# 10       F
# 11       P
# 12       P
# 13       P
# 14       P
# 15       F
# 16       F
# 17     NaN
# 18       P
# 19       P
# 20       F
# 21       F
# 22       P
# 23       P
# 24       P
# 25       F
# 26       F
# 27       F
# 28       P
# 29       P
# ..     ...
# 103      P
# 104      P
# 105    NaN
# 106      F
# 107      F
# 108      P
# 109      P
# 110      P
# 111      F
# 112      P
# 113      P
# 114      P
# 115      P
# 116      F
# 117      P
# 118      P
# 119      P
# 120      P
# 121      F
# 122      F
# 123      P
# 124      P
# 125      P
# 126      F
# 127      P
# 128      P
# 129      F
# 130      P
# 131      F
# 132      P
#
# [133 rows x 10 columns]

# %%
# dftotalmarks['APPLIED MATHEMATICS III-TOT'].apply(lambda x:int(x>40))
# dftotalmarks['THERMODYNAMICS-TOT'].apply(lambda x:int(x>40))
# dftotalmarks['STRENGTH OF MATERIALS-TOT'].apply(lambda x:int(x>40))
# dftotalmarks['PRODUCTION PROCESS I-TOT'].apply(lambda x:int(x>40))
# dftotalmarks['MATERIAL TECHNOLOGY-TOT'].apply(lambda x:int(x>40))

# %%
df = pd.read_excel('RA.xlsx')
# df = df.drop(['Unnamed: 1','Unnamed: 28','Unnamed: 29'], axis=1)
df.head()
# Out:
#                                           Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4  Result Sheet for S.E., Mechanical Engineering,...        NaN        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9  ... Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24  \
# 0        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 1        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 2        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 3        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 4        NaN  ...         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 30 columns]

# %%
df.dropna(how="all", inplace=True)

# %%
df
# Out:
#                                             Unnamed: 0 Unnamed: 1  \
# 4    Result Sheet for S.E., Mechanical Engineering,...        NaN
# 5                                            Courses →        NaN
# 6                                                  NaN        NaN
# 7                          Seat No / Name of Student ↓        NaN
# 8                                                  NaN       MaxM
# 9                                                  NaN       MinM
# 10                                               13001     MarksO
# 11                                 ABHIJITH SHAH  NITA      Grade
# 12                                               13002     MarksO
# 13                    AGRAWAL AKHILESH SANJAY ANURADHA      Grade
# 14                                               13003     MarksO
# 15                           AGRAWAL RONAK ANIL VARSHA      Grade
# 16                                               13004     MarksO
# 17                    ALDAR ROHAN PANDHARINATH SANGITA      Grade
# 18                                               13005     MarksO
# 19                       AWATE TEJAS PANDURANG RANJANA      Grade
# 20                                               13006     MarksO
# 21                       BHALERAO ASHUTOSH VIJAY AARTI      Grade
# 22                                               13007     MarksO
# 23                       / BHARAMBE DAMINI NITIN JYOTI      Grade
# 24                                               13008     MarksO
# 25                         BHOIR CHIRAG PRADEEP PRACHI      Grade
# 26                                               13009     MarksO
# 27                             BHURKE SOHAM NITIN NEHA      Grade
# 28                                               13010     MarksO
# 29                         BOKKA HARISH TATARAO KUSUMA      Grade
# 30                                               13011     MarksO
# 31                 BORHADE SHUBHAM GORAKHNATH VAISHALI      Grade
# 32                                               13012     MarksO
# 33                 CHACHARE AKSHAY DNYANESHWAR VANDANA      Grade
# ..                                                 ...        ...
# 246                                              13120     MarksO
# 247              SINGH ANUP SHATRUJEETSINGH REETASINGH      Grade
# 248                                              13121     MarksO
# 249                       SUTAR NISHANT ASHOK VAISHALI      Grade
# 250                                              13122     MarksO
# 251                   SUVARNA AAKASH LEELADHAR SUREKHA      Grade
# 252                                              13123     MarksO
# 253                / TAMBADKAR KSHITIJA PRAKASH RAKSHA      Grade
# 254                                              13124     MarksO
# 255                    / THAKUR UTKARSHA SANJAY NILIMA      Grade
# 256                                              13125     MarksO
# 257                      TODANKAR SWARAJ VIKAS VISHAYA      Grade
# 258                                              13126     MarksO
# 259                            TOMAR ABHIJEET D SUNITA      Grade
# 260                                              13127     MarksO
# 261                    UBALE KAUSTUBH HARILAL HARSHADA      Grade
# 262                                              13128     MarksO
# 263                      VANJARE SIDDHESH VISHNU VEENA      Grade
# 264                                              13129     MarksO
# 265                  VENGURLEKAR PRASAD SHRIDHAR SEEMA      Grade
# 266                                              13130     MarksO
# 267                      VHAVALE PANKAJ SANJAY MANISHA      Grade
# 268                                              13131     MarksO
# 269                          WAGH KAMLESH ARUN SUREKHA      Grade
# 270                                              13132     MarksO
# 271                         / WANI PRIYANKA BIJU NISHA      Grade
# 272                                              13133     MarksO
# 273                   YADAV PRATHMESH BHUPESH VAISHALI      Grade
# 274                                              13134     MarksO
# 275                        YEOLA SAURABH SUNIL VANDANA      Grade
#
#                   Unnamed: 2 Unnamed: 3 Unnamed: 4      Unnamed: 5 Unnamed: 6  \
# 4                        NaN        NaN        NaN             NaN        NaN
# 5                     MEC301        NaN        NaN          MEC302        NaN
# 6    APPLIED MATHEMATICS III        NaN        NaN  THERMODYNAMICS        NaN
# 7                       ESE         IA         TOT            ESE         IA
# 8                         80         20        100              80         20
# 9                         32          8         40              32          8
# 10                       34E        02F         36             15F        09E
# 11                         P          F          F               F          E
# 12                       39E        05F         44             21F        09E
# 13                         E          F          F               F          E
# 14                        47         14         61              39         14
# 15                         D          B          C               E          B
# 16                       35E        05F         40             21F        09E
# 17                         P          F          F               F          E
# 18                       00F        05F          5             10F        08E
# 19                         F          F          F               F          P
# 20                        39          9         48              39         15
# 21                         E          E          E               E          A
# 22                        66         18         84              67         17
# 23                         O          O          O               O          O
# 24                        69         17         86              45         13
# 25                         O          O          O               D          C
# 26                        51         16         67              32         13
# 27                         C          O          C               P          C
# 28                        62         18         80              44         14
# 29                         A          O          O               D          B
# 30                       65E        13E         78             19F        11E
# 31                         O          C          A               F          D
# 32                        55          9         64              45         11
# 33                         C          E          C               D          D
# ..                       ...        ...        ...             ...        ...
# 246                       53          9         62              56         11
# 247                        C          E          C               B          D
# 248                       61         17         78              58         12
# 249                        A          O          A               B          C
# 250                       46         12         58              40         12
# 251                        D          C          D               D          C
# 252                      50E        09E         59             21F        10E
# 253                        C          E          D               F          D
# 254                      32E        07F         39             32E        12E
# 255                        P          F          F               P          C
# 256                       48         13         61              52         13
# 257                        C          C          C               C          C
# 258                       66         17         83              41         15
# 259                        O          O          O               D          A
# 260                       55         16         71              49         15
# 261                        C          O          B               C          A
# 262                      14F        08E         22             04F        09E
# 263                        F          P          F               F          E
# 264                       37         11         48              43         15
# 265                        E          D          E               D          A
# 266                       49         13         62              40         14
# 267                        C          C          C               D          B
# 268                      35E        06F         41             17F        08E
# 269                        P          F          F               F          P
# 270                       35          8         43              32          9
# 271                        P          P          P               P          E
# 272                      32E        08E         40             16F        09E
# 273                        P          P          P               F          E
# 274                       65         17         82              49         18
# 275                        O          O          O               C          O
#
#     Unnamed: 7             Unnamed: 8 Unnamed: 9  ...            Unnamed: 20  \
# 4          NaN                    NaN        NaN  ...                    NaN
# 5          NaN                 MEC303        NaN  ...                 MEL302
# 6          NaN  STRENGTH OF MATERIALS        NaN  ...  STRENGTH OF MATERIALS
# 7          TOT                   ESE         IA   ...                  PR OR
# 8          100                     80         20  ...                     25
# 9           40                     32          8  ...                     10
# 10          24                    26F        04F  ...                    18E
# 11           F                      F          F  ...                      B
# 12          30                    41E        09E  ...                    15E
# 13           F                      D          E  ...                      C
# 14          53                     64         12  ...                     17
# 15           D                      O          C  ...                      C
# 16          30                    38E        08E  ...                    16E
# 17           F                      E          P  ...                      C
# 18          18                    22F        08E  ...                    18E
# 19           F                      F          P  ...                      B
# 20          54                     54         14  ...                     23
# 21           D                      C          B  ...                      O
# 22          84                     65         13  ...                     20
# 23           O                      O          C  ...                      O
# 24          58                     64         12  ...                     19
# 25           D                      O          C  ...                      A
# 26          45                     68         14  ...                     19
# 27           E                      O          B  ...                      A
# 28          58                     46         15  ...                     18
# 29           D                      D          A  ...                      B
# 30          30                    45E        08E  ...                    17E
# 31           F                      D          P  ...                      C
# 32          56                     34         14  ...                     22
# 33           D                      P          B  ...                      O
# ..         ...                    ...        ...  ...                    ...
# 246         67                     55         12  ...                     20
# 247          C                      C          C  ...                      O
# 248         70                     63          9  ...                     20
# 249          B                      A          E  ...                      O
# 250         52                     41         15  ...                     19
# 251          D                      D          A  ...                      A
# 252         31                    36E        08E  ...                    18E
# 253          F                      E          P  ...                      B
# 254         44                    20F        08E  ...                    18E
# 255          P                      F          P  ...                      B
# 256         65                     55         10  ...                     21
# 257          C                      C          D  ...                      O
# 258         56                     57         13  ...                     20
# 259          D                      B          C  ...                      O
# 260         64                     68         10  ...                     21
# 261          C                      O          D  ...                      O
# 262         13                    21F        08E  ...                    18E
# 263          F                      F          P  ...                      B
# 264         58                     32          9  ...                     19
# 265          D                      P          E  ...                      A
# 266         54                     46         11  ...                     20
# 267          D                      D          D  ...                      O
# 268         25                    13F        08E  ...                    18E
# 269          F                      F          P  ...                      B
# 270         41                     32          8  ...                     18
# 271          P                      P          P  ...                      B
# 272         25                    32E        07F  ...                    16E
# 273          F                      P          F  ...                      C
# 274         67                     57         13  ...                     23
# 275          C                      B          C  ...                      O
#
#     Unnamed: 21 Unnamed: 22          Unnamed: 23              Unnamed: 24  \
# 4           NaN         NaN                  NaN                      NaN
# 5           NaN         NaN               MEL303                   MEL304
# 6           NaN         NaN  MATERIAL TECHNOLOGY  MACHINE SHOP PRACTICE I
# 7            TW         TOT                   TW                       TW
# 8            25          50                   25                       50
# 9            10          20                   10                       20
# 10          19E          37                  16E                      41E
# 11            A           B                    C                        O
# 12          18E          33                  17E                      35E
# 13            B           C                    C                        B
# 14           18          35                   18                       34
# 15            B           B                    B                        C
# 16          17E          33                  13E                      32E
# 17            C           C                    D                        C
# 18          19E          37                  16E                      34E
# 19            A           B                    C                        C
# 20           24          47                   20                       40
# 21            O           O                    O                        O
# 22           21          41                   18                       41
# 23            O           O                    B                        O
# 24           22          41                   21                       38
# 25            O           O                    O                        A
# 26           21          40                   20                       38
# 27            O           O                    O                        A
# 28           20          38                   19                       38
# 29            O           A                    A                        A
# 30          20E          37                  19E                      39E
# 31            O           B                    A                        A
# 32           23          45                   19                       40
# 33            O           O                    A                        O
# ..          ...         ...                  ...                      ...
# 246          21          41                   20                       35
# 247           O           O                    O                        B
# 248          23          43                   19                       38
# 249           O           O                    A                        A
# 250          20          39                   19                       40
# 251           O           A                    A                        O
# 252         20E          38                  17E                      38E
# 253           O           A                    C                        A
# 254         20E          38                  18E                      41E
# 255           O           A                    B                        O
# 256          21          42                   18                       40
# 257           O           O                    B                        O
# 258          22          42                   21                       40
# 259           O           O                    O                        O
# 260          24          45                   20                       40
# 261           O           O                    O                        O
# 262         20E          38                  18E                      41E
# 263           O           A                    B                        O
# 264          19          38                   19                       42
# 265           A           A                    A                        O
# 266          21          41                   17                       40
# 267           O           O                    C                        O
# 268         19E          37                  20E                      40E
# 269           A           B                    O                        O
# 270          19          37                   20                       38
# 271           A           B                    O                        A
# 272         17E          33                  19E                      38E
# 273           C           C                    A                        A
# 274          25          48                   22                       42
# 275           O           O                    O                        O
#
#     Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29
# 4           NaN         NaN         NaN         NaN         NaN
# 5         TOTAL  SGPI (GPA)      RESULT        CGPI         RLE
# 6           NaN         NaN         NaN         NaN         NaN
# 7           NaN         NaN         NaN         NaN         NaN
# 8           725         NaN         NaN         NaN         NaN
# 9           NaN         NaN         NaN         NaN         NaN
# 10          344        2.96           F        2.96         NaN
# 11          NaN         NaN         NaN         NaN         NaN
# 12          366        3.69           F        3.69         NaN
# 13          NaN         NaN         NaN         NaN         NaN
# 14          471        7.23           P        7.23         NaN
# 15          NaN         NaN         NaN         NaN         NaN
# 16          333        3.12           F        3.12         NaN
# 17          NaN         NaN         NaN         NaN         NaN
# 18          323        3.65           F        3.65         NaN
# 19          NaN         NaN         NaN         NaN         NaN
# 20          517        7.92           P        7.92         NaN
# 21          NaN         NaN         NaN         NaN         NaN
# 22          584        9.35           P        9.35         NaN
# 23          NaN         NaN         NaN         NaN         NaN
# 24          521        8.08           P        8.08         NaN
# 25          NaN         NaN         NaN         NaN         NaN
# 26          477        7.46           P        7.46         NaN
# 27          NaN         NaN         NaN         NaN         NaN
# 28          492        7.69           P        7.69         NaN
# 29          NaN         NaN         NaN         NaN         NaN
# 30          433        6.08           F        6.08         NaN
# 31          NaN         NaN         NaN         NaN         NaN
# 32          516        7.85           P        7.85         NaN
# 33          NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...
# 246         488        7.42           P        7.42         NaN
# 247         NaN         NaN         NaN         NaN         NaN
# 248         529        8.31           P        8.31         NaN
# 249         NaN         NaN         NaN         NaN         NaN
# 250         458           7           P           7         NaN
# 251         NaN         NaN         NaN         NaN         NaN
# 252         395        5.12           F        5.12         NaN
# 253         NaN         NaN         NaN         NaN         NaN
# 254         363        4.04           F        4.04         NaN
# 255         NaN         NaN         NaN         NaN         NaN
# 256         531        8.12           P        8.12         NaN
# 257         NaN         NaN         NaN         NaN         NaN
# 258         519        8.12           P        8.12         NaN
# 259         NaN         NaN         NaN         NaN         NaN
# 260         525        8.15           P        8.15         NaN
# 261         NaN         NaN         NaN         NaN         NaN
# 262         318        3.08           F        3.08         NaN
# 263         NaN         NaN         NaN         NaN         NaN
# 264         433         6.5           P         6.5         NaN
# 265         NaN         NaN         NaN         NaN         NaN
# 266         432        6.65           P        6.65         NaN
# 267         NaN         NaN         NaN         NaN         NaN
# 268         334        3.12           F        3.12         NaN
# 269         NaN         NaN         NaN         NaN         NaN
# 270         364        5.23           P        5.23         NaN
# 271         NaN         NaN         NaN         NaN         NaN
# 272         324        2.73           F        2.73         NaN
# 273         NaN         NaN         NaN         NaN         NaN
# 274         550        8.73           P        8.73         NaN
# 275         NaN         NaN         NaN         NaN         NaN
#
# [272 rows x 30 columns]
