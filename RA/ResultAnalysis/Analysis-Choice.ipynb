# %%
#LIBRARIES
import pandas as pd
import matplotlib.pyplot as plt

# %%
############################################################

# READ FILE + DROP NULL COLUMNS
# original_file = pd.read_excel('data/Check.xlsx')
# original_file = pd.read_excel('data/Result-Format1.xlsx')
# original_file = pd.read_excel('data/Result-Format2.xls')
original_file = pd.read_excel('data/Result-Format3-Elective.xls')
# original_file = pd.read_excel('data/Result-Format3-Elective2.xls')

# remove rows wiht all na
original_file.dropna(how="all", inplace=True)

# remove redundant column
original_file.drop(['Unnamed: 1'], axis=1, inplace=True)
original_file = original_file.iloc[:,:-1]

# scrap part of original dataframe
original_file1 = original_file.iloc[3:,:]
original_file1 = original_file1.dropna(axis='columns', how='all')

# regenerating old file for selected columns only
original_file = original_file.loc[:,original_file1.columns]

############################################################

# %%
# original_file.head()

# %%
############################################################

# Working with Header for further use
curr_header = [str(i) for i in original_file.iloc[2,:].values]
add_details = [str(i) for i in original_file.iloc[3,:].values]

header = ['SEAT', 'TOTAL', 'SGPI', 'RESULT']

for i in range(1, len(curr_header)-4):
    j = i
    while curr_header[j] == 'nan':
        j = j - 1
    header.insert(-3,(curr_header[j].strip()+'-'+add_details[i].strip()))

header_later = header.copy()
header_later.insert(1, 'NAME')

############################################################

# %%
# header

# %%
############################################################

# Creating a list of subject names and codes and mapping them
subjectlist = [i for i in curr_header if i != 'nan']
subjectcode = [i for i in original_file.iloc[1,:].values[1:-4] if str(i) != 'nan']
subjectcodes = dict(zip(subjectcode,subjectlist))

############################################################

# %%
# subjectcodes

# %%
############################################################

# Creating a dataframe to work on
df = original_file1.iloc[:,:]
df = df.loc[df['Unnamed: 2'].isna() == False]

# removing CGPA column
df = df.iloc[:,:-1]

df.columns = header

df = df.iloc[3:,:]

# dataframe to store marks
dfmarks = df.iloc[::2]

# dataframe that stores names
dfnames = df.iloc[1::2]

# adding names to the marks dataframe
dfmarks = dfmarks.copy()
dfmarks['NAME'] = dfnames.loc[:, 'SEAT'].values
dfmarks = dfmarks.loc[:,header_later]

dfmarks.index = pd.RangeIndex(1,len(dfmarks.index)+1)


############################################################

# %%
# len(original_file1.columns)

# %%
dfmarks
# Out:
#      SEAT                                        NAME MICROPROCESSOR-ESE  \
# 1   45001              AMBILPURE SAGAR SURENDRA MEENA                 50
# 2   45002              / ANGNE HEMALI KISHORE KAUMUDI                 56
# 3   45003          ATKARI ADITYA CHANDRAKANT SHARMILA                 63
# 4   45004          CHAUDHARI RUTURAJ NARENDRA MANISHA                 33
# 5   45005                  CHAVAN ADITYA RAMESH JYOTI                 55
# 6   45006                 CHHAPRA UZAIR ASIF NAUSHEEN                 54
# 7   45007         DHARGALKAR NISHANT SHAILESH MANISHA                 42
# 8   45008                   / DUDHAL SHWETA RAJU USHA                 63
# 9   45009                 GAWDE VARNESH PRASHANT ULKA                 35
# 10  45010                 GHOJARIA SAAD IMTIAZ RUMANA                 36
# 11  45011            JADEJA HARPALSINH TANUBHA TARABA                 50
# 12  45012                JANGID MUKUL DAYANAND LALITA                22F
# 13  45013                  KASALE SANKALP NARESH NEHA                 36
# 14  45014            KHAN IMRAN KHURSHID ALAM SHABANA                 33
# 15  45015                  KOLEKAR AAKASH ANIL SAVITA                 69
# 16  45016              MORYE MANDAR VISHWANATH RUPALI                 32
# 17  45017          / MUTHA AKANKSHA AMARCHAND SANGITA                 52
# 18  45018                  NAIK AKSHAY HEMANT HEMANGI                 44
# 19  45019                / PAGAR RIDDHI KISAN SANDHYA                 54
# 20  45020               / PANDA DEEPALI SURJA MINNOTI                 50
# 21  45021             PANDEY SHREYAS SURENDRA MADHURI                 53
# 22  45022  PASI PIYUSH SINGH UMESH CHANDRA JWALAMUKHI                 51
# 23  45023                 PATEL DARSHAN RANJIT BHAVNA                 39
# 24  45024               / PATEL DISHA DHARMESH AMPARA                17F
# 25  45025         / PATEL KANISHKA ALPESHBHAI MITABEN                 66
# 26  45026               PATHAK VAIBHAV SUSHIL KANCHAN                 44
# 27  45027               PATIL BHUSHAN BHAURAO VANDANA                 49
# 28  45028               PEDNEKAR MIHIR SANDEEP TRUPTI                 42
# 29  45029            PUSEGAONKAR SAMEER SATISH SUSHMA                 45
# 30  45030              / RAJE GAYATRI SURYAKANT ANITA                 55
# ..    ...                                         ...                ...
# 32  45032                RATH BUDDHADITYA MITALI RATH                32E
# 33  45033                RAUT PRANAV VIRENDRA PRERENA                 44
# 34  45034              / RAWAT SHIVANI SURENDER KANTI                 54
# 35  45035                   REPALE VIVEK RAMRAO SEEMA                 43
# 36  45036               / ROY SRIJITA NIRANJAN SUJATA                35E
# 37  45037                  SANKHE ARNAV KISHOR KAVITA                 50
# 38  45038                   SARAWGI AMAN DEEPAK KOMAL                 60
# 39  45039           SATPUTE PRATIK VIJAYKUMAR ARCHANA                 55
# 40  45040                  SAWANT MOHIT SUHAS NIRMALA                 50
# 41  45041                / SAXENA AKSHI ASHEEM NIRAJA                 62
# 42  45042      SHAIKH MD ABUZAR MD TAHMIL NUZHAT BANO                 56
# 43  45043                   SHARMA AJAY PAPPU SANGITA                 68
# 44  45044         SHARMA AMIT KUMAR RAMCHANDRA SHARDA                 32
# 45  45045                 / SHARMA SONAL RAJESH MEERA                 40
# 46  45046               / SHETE PRANATI SANJAY SARITA                 40
# 47  45047                / SHETTY VAISHNI ASHOKA USHA                 34
# 48  45048            SINGH AAYUSH INDRA PRATAP CHETNA                 57
# 49  45049        SONPAROTE DEEPANSHU RAJKUMAR SADHANA                 67
# 50  45050                   SORTE KUNAL YOGIRAJ SEEMA                 32
# 51  45051               SURYAWANSHI HITESH VIJAY LILA                 33
# 52  45052              TALEKAR NITISH PRAVIN SANGEETA                 56
# 53  45053                     / TANVI VINAYARAJ REKHA                 62
# 54  45054            TIKE YASH CHANDRASHEKHAR MANISHA                16F
# 55  45055                  TIWARI SATYAM DINESH MANJU                 58
# 56  45056              UPADHYAY SUDHANSHU BHARAT LATA                 39
# 57  45057                  VAGE SARTHAK GOVIND SUJATA                 54
# 58  45058             WAGHMODE AMEY SHRIKRISHNA REKHA                 59
# 59  45059              WANODE SARVESH SANJAY MANJUSHA                 47
# 60  45060              / YADAV MAMTA RAMMANOHAR VIMLA                 53
# 61  45061              / ZUTSHI DEEPALI RAJIV VANDANA                 65
#
#    MICROPROCESSOR-IA MICROPROCESSOR-TOT DATABASE MANAGEMENT SYSTEM-ESE  \
# 1                 12                 62                             51
# 2                 15                 71                             57
# 3                 17                 80                             54
# 4                 09                 42                             43
# 5                 10                 65                             59
# 6                 11                 65                             53
# 7                 13                 55                             58
# 8                 15                 78                             60
# 9                 14                 49                             53
# 10                11                 47                             54
# 11                14                 64                             49
# 12               10E                 32                            41E
# 13                09                 45                             55
# 14                12                 45                             58
# 15                18                 87                             60
# 16                12                 44                             51
# 17                10                 62                             54
# 18                13                 57                             54
# 19                18                 72                             59
# 20                15                 65                             60
# 21                11                 64                             54
# 22                18                 69                             50
# 23                14                 53                             53
# 24               11E                 28                            49E
# 25                13                 79                             59
# 26                11                 55                             47
# 27                10                 59                             53
# 28                10                 52                             51
# 29                11                 56                             48
# 30                20                 75                             52
# ..               ...                ...                            ...
# 32               04F                 36                            39E
# 33                13                 57                             42
# 34                15                 69                             55
# 35                08                 51                             39
# 36               10E                 45                            45E
# 37                13                 63                             52
# 38                10                 70                             54
# 39                12                 67                             53
# 40                11                 61                             55
# 41                11                 73                             53
# 42                16                 72                             51
# 43                15                 83                             57
# 44                11                 43                             55
# 45                13                 53                             59
# 46                13                 53                             57
# 47                08                 42                             48
# 48                15                 72                             55
# 49                18                 85                             58
# 50                09                 41                             48
# 51                08                 41                             47
# 52                16                 72                             51
# 53                09                 71                             54
# 54               05F                 21                            34E
# 55                14                 72                             45
# 56                10                 49                             52
# 57                11                 65                             55
# 58                16                 75                             61
# 59                11                 58                             53
# 60                12                 65                             58
# 61                14                 79                             51
#
#    DATABASE MANAGEMENT SYSTEM-IA DATABASE MANAGEMENT SYSTEM-TOT  \
# 1                             12                             63
# 2                             18                             75
# 3                             17                             71
# 4                             12                             55
# 5                             16                             75
# 6                             18                             71
# 7                             18                             76
# 8                             17                             77
# 9                             16                             69
# 10                            12                             66
# 11                            15                             64
# 12                           11E                             52
# 13                            14                             69
# 14                            13                             71
# 15                            19                             79
# 16                            15                             66
# 17                            13                             67
# 18                            16                             70
# 19                            13                             72
# 20                            18                             78
# 21                            17                             71
# 22                            19                             69
# 23                            14                             67
# 24                           11E                             60
# 25                            14                             73
# 26                            17                             64
# 27                            14                             67
# 28                            14                             65
# 29                            17                             65
# 30                            18                             70
# ..                           ...                            ...
# 32                           09E                             48
# 33                            15                             57
# 34                            16                             71
# 35                            10                             49
# 36                           13E                             58
# 37                            15                             67
# 38                            17                             71
# 39                            13                             66
# 40                            12                             67
# 41                            16                             69
# 42                            16                             67
# 43                            17                             74
# 44                            12                             67
# 45                            18                             77
# 46                            16                             73
# 47                            12                             60
# 48                            17                             72
# 49                            14                             72
# 50                            14                             62
# 51                            12                             59
# 52                            16                             67
# 53                            14                             68
# 54                           10E                             44
# 55                            15                             60
# 56                            13                             65
# 57                            13                             68
# 58                            15                             76
# 59                            17                             70
# 60                            14                             72
# 61                            16                             67
#
#    COMPUTER NETWORK-ESE COMPUTER NETWORK-IA  ...  \
# 1                    43                  13  ...
# 2                    52                  18  ...
# 3                    59                  19  ...
# 4                    39                  10  ...
# 5                    49                  15  ...
# 6                    48                  19  ...
# 7                    52                  18  ...
# 8                    58                  19  ...
# 9                    51                  19  ...
# 10                   44                  12  ...
# 11                   45                  13  ...
# 12                  33E                 13E  ...
# 13                   50                  15  ...
# 14                   33                  13  ...
# 15                   56                  20  ...
# 16                   38                  14  ...
# 17                   54                  13  ...
# 18                   47                  12  ...
# 19                   57                  15  ...
# 20                   46                  17  ...
# 21                   57                  13  ...
# 22                   61                  19  ...
# 23                   54                  12  ...
# 24                  53E                 11E  ...
# 25                   58                  18  ...
# 26                   47                  15  ...
# 27                   39                  10  ...
# 28                   40                  11  ...
# 29                   44                  14  ...
# 30                   47                  18  ...
# ..                  ...                 ...  ...
# 32                  37E                 09E  ...
# 33                   47                  13  ...
# 34                   53                  13  ...
# 35                   42                  10  ...
# 36                  38E                 14E  ...
# 37                   57                  12  ...
# 38                   55                  13  ...
# 39                   54                  14  ...
# 40                   57                  12  ...
# 41                   44                  13  ...
# 42                   53                  14  ...
# 43                   60                  14  ...
# 44                   54                  12  ...
# 45                   57                  15  ...
# 46                   49                  15  ...
# 47                   44                  11  ...
# 48                   46                  14  ...
# 49                   57                  16  ...
# 50                   50                  11  ...
# 51                   54                  10  ...
# 52                   46                  17  ...
# 53                   51                  11  ...
# 54                  32E                 07F  ...
# 55                   49                  12  ...
# 56                   42                  12  ...
# 57                   55                  13  ...
# 58                   63                  14  ...
# 59                   57                  13  ...
# 60                   50                  14  ...
# 61                   61                  15  ...
#
#    DATABASE & INFORMATION SYSTEM LAB-PR OR  \
# 1                                       21
# 2                                       23
# 3                                       23
# 4                                       18
# 5                                       20
# 6                                       22
# 7                                       21
# 8                                       19
# 9                                       22
# 10                                      22
# 11                                      20
# 12                                     19E
# 13                                      19
# 14                                      20
# 15                                      23
# 16                                      23
# 17                                      16
# 18                                      21
# 19                                      21
# 20                                      22
# 21                                      19
# 22                                      23
# 23                                      18
# 24                                     20E
# 25                                      19
# 26                                      19
# 27                                      17
# 28                                      13
# 29                                      18
# 30                                      22
# ..                                     ...
# 32                                     10E
# 33                                      18
# 34                                      20
# 35                                      18
# 36                                     18E
# 37                                      18
# 38                                      19
# 39                                      20
# 40                                      19
# 41                                      19
# 42                                      19
# 43                                      21
# 44                                      19
# 45                                      21
# 46                                      20
# 47                                      19
# 48                                      22
# 49                                      19
# 50                                      19
# 51                                      18
# 52                                      22
# 53                                      19
# 54                                     11E
# 55                                      20
# 56                                      19
# 57                                      18
# 58                                      19
# 59                                      19
# 60                                      18
# 61                                      20
#
#    DATABASE & INFORMATION SYSTEM LAB-TW DATABASE & INFORMATION SYSTEM LAB-TOT  \
# 1                                    21                                    42
# 2                                    23                                    46
# 3                                    24                                    47
# 4                                    18                                    36
# 5                                    23                                    43
# 6                                    21                                    43
# 7                                    21                                    42
# 8                                    22                                    41
# 9                                    21                                    43
# 10                                   18                                    40
# 11                                   20                                    40
# 12                                  18E                                    37
# 13                                   18                                    37
# 14                                   22                                    42
# 15                                   23                                    46
# 16                                   23                                    46
# 17                                   18                                    34
# 18                                   22                                    43
# 19                                   21                                    42
# 20                                   22                                    44
# 21                                   19                                    38
# 22                                   24                                    47
# 23                                   18                                    36
# 24                                  18E                                    38
# 25                                   18                                    37
# 26                                   18                                    37
# 27                                   18                                    35
# 28                                   12                                    25
# 29                                   19                                    37
# 30                                   21                                    43
# ..                                  ...                                   ...
# 32                                  12E                                    22
# 33                                   19                                    37
# 34                                   19                                    39
# 35                                   14                                    32
# 36                                  19E                                    37
# 37                                   18                                    36
# 38                                   20                                    39
# 39                                   19                                    39
# 40                                   20                                    39
# 41                                   18                                    37
# 42                                   19                                    38
# 43                                   20                                    41
# 44                                   18                                    37
# 45                                   22                                    43
# 46                                   19                                    39
# 47                                   18                                    37
# 48                                   23                                    45
# 49                                   18                                    37
# 50                                   19                                    38
# 51                                   17                                    35
# 52                                   23                                    45
# 53                                   18                                    37
# 54                                  12E                                    23
# 55                                   19                                    39
# 56                                   18                                    37
# 57                                   19                                    37
# 58                                   20                                    39
# 59                                   20                                    39
# 60                                   19                                    37
# 61                                   19                                    39
#
#    WEB DESIGN LAB-PR OR WEB DESIGN LAB-TW WEB DESIGN LAB-TOT  \
# 1                    23                24                 47
# 2                    18                22                 40
# 3                    18                23                 41
# 4                    22                20                 42
# 5                    23                23                 46
# 6                    23                24                 47
# 7                    21                24                 45
# 8                    21                19                 40
# 9                    21                21                 42
# 10                   23                24                 47
# 11                   19                19                 38
# 12                  19E               19E                 38
# 13                   19                22                 41
# 14                   23                23                 46
# 15                   24                24                 48
# 16                   20                23                 43
# 17                   17                21                 38
# 18                   22                24                 46
# 19                   19                22                 41
# 20                   23                24                 47
# 21                   22                21                 43
# 22                   22                23                 45
# 23                   23                22                 45
# 24                  18E               22E                 40
# 25                   19                23                 42
# 26                   20                21                 41
# 27                   19                18                 37
# 28                   13                14                 27
# 29                   18                20                 38
# 30                   23                24                 47
# ..                  ...               ...                ...
# 32                  12E               13E                 25
# 33                   23                20                 43
# 34                   23                19                 42
# 35                   14                14                 28
# 36                  07F               18E                 25
# 37                   19                21                 40
# 38                   19                21                 40
# 39                   18                22                 40
# 40                   22                21                 43
# 41                   23                23                 46
# 42                   23                22                 45
# 43                   23                22                 45
# 44                   20                21                 41
# 45                   22                22                 44
# 46                   19                19                 38
# 47                   17                19                 36
# 48                   21                24                 45
# 49                   23                24                 47
# 50                   20                21                 41
# 51                   22                20                 42
# 52                   23                24                 47
# 53                   22                23                 45
# 54                  20E               15E                 35
# 55                   20                21                 41
# 56                   23                22                 45
# 57                   18                22                 40
# 58                   23                22                 45
# 59                   22                24                 46
# 60                   18                22                 40
# 61                   19                22                 41
#
#    BUSINESS COMMUNICATION & ETHICS-TW TOTAL  SGPI RESULT
# 1                                  41   534  7.85      P
# 2                                  43   605  9.26      P
# 3                                  44   620  9.41      P
# 4                                  40   449  6.26      P
# 5                                  41   546  8.26      P
# 6                                  43   547  7.96      P
# 7                                  43   577  8.67      P
# 8                                  41   599  9.41      P
# 9                                  42   541  7.93      P
# 10                                 41   480  6.93      P
# 11                                 42   531  7.85      P
# 12                                41E   436  5.85      F
# 13                                 39   491  7.04      P
# 14                                 41   520  7.59      P
# 15                                 41   625  9.56      P
# 16                                 39   502  7.11      P
# 17                                 42   519  7.52      P
# 18                                 42   540  7.93      P
# 19                                 45   580  8.81      P
# 20                                 44   592  8.67      P
# 21                                 40   541  8.19      P
# 22                                 42   610  8.96      P
# 23                                 40   536  7.85      P
# 24                                46E   491   6.7      F
# 25                                 46   595  8.89      P
# 26                                 45   526   7.7      P
# 27                                 40   490  7.11      P
# 28                                 38   460  7.04      P
# 29                                 40   495  7.37      P
# 30                                 43   595  8.67      P
# ..                                ...   ...   ...    ...
# 32                                35E   368  4.11      F
# 33                                 42   501   7.3      P
# 34                                 44   562  8.19      P
# 35                                 38   417  6.15      P
# 36                                40E   390  4.93      F
# 37                                 42   545  8.04      P
# 38                                 43   548   8.3      P
# 39                                 40   560   8.3      P
# 40                                 44   543  8.04      P
# 41                                 44   546  7.93      P
# 42                                 45   577  8.33      P
# 43                                 45   613  9.11      P
# 44                                 42   503  7.33      P
# 45                                 44   546  8.19      P
# 46                                 44   522  7.67      P
# 47                                 44   445  6.26      P
# 48                                 44   559  8.22      P
# 49                                 43   593  8.89      P
# 50                                 44   497  7.26      P
# 51                                 40   458  6.44      P
# 52                                 42   564  8.22      P
# 53                                 44   549  8.19      P
# 54                                41E   338  3.33      F
# 55                                 42   549   8.3      P
# 56                                 44   498  7.37      P
# 57                                 44   541  7.93      P
# 58                                 45   594  9.15      P
# 59                                 45   551  8.19      P
# 60                                 39   541  8.07      P
# 61                                 46   577  8.74      P
#
# [61 rows x 33 columns]

# %%
############################################################

# to clean the columns

def clean(x):
    if x == 'Ab':
        return int(0)
    ########################
    ## Might need changes
    if '\r' in str(x):
        x = x[:x.index('\r')]
    ########################
    x = list(str(x))
    if x[-1] == 'E' or  x[-1] == 'F':
        return "".join(x[:-1]).strip()
    else:
        return "".join(x)
    
for i in range(1,len(dfmarks.columns)-3):
    dfmarks.iloc[:,i] = dfmarks.iloc[:,i].apply(clean)
    
############################################################

# %%
# subjectlist

# %%
############################################################

# fetching the total columns

labstr = subjectcode[-1][:3]
totalsubs = []
for k,v in subjectcodes.items():
    if labstr not in k:
        totalsubs.append(v)
if len(totalsubs) == 0:
    totalsubs = subjectlist.copy()
df_header = list(dfmarks.columns)
totalcols = df_header[:2] + [str(i.strip()+'-TOT') for i in totalsubs] + df_header[-3:]
# totalcols

############################################################

# %%
# totalcols

# %%
############################################################

# TOTAL MARKS DATAFRAME

dftotalmarks = dfmarks[totalcols]

dftotalmarks = dftotalmarks.loc[:,~dftotalmarks.columns.duplicated()]
############################################################

# %%
dftotalmarks
# Out:
#      SEAT                                        NAME MICROPROCESSOR-TOT  \
# 1   45001              AMBILPURE SAGAR SURENDRA MEENA                 62
# 2   45002              / ANGNE HEMALI KISHORE KAUMUDI                 71
# 3   45003          ATKARI ADITYA CHANDRAKANT SHARMILA                 80
# 4   45004          CHAUDHARI RUTURAJ NARENDRA MANISHA                 42
# 5   45005                  CHAVAN ADITYA RAMESH JYOTI                 65
# 6   45006                 CHHAPRA UZAIR ASIF NAUSHEEN                 65
# 7   45007         DHARGALKAR NISHANT SHAILESH MANISHA                 55
# 8   45008                   / DUDHAL SHWETA RAJU USHA                 78
# 9   45009                 GAWDE VARNESH PRASHANT ULKA                 49
# 10  45010                 GHOJARIA SAAD IMTIAZ RUMANA                 47
# 11  45011            JADEJA HARPALSINH TANUBHA TARABA                 64
# 12  45012                JANGID MUKUL DAYANAND LALITA                 32
# 13  45013                  KASALE SANKALP NARESH NEHA                 45
# 14  45014            KHAN IMRAN KHURSHID ALAM SHABANA                 45
# 15  45015                  KOLEKAR AAKASH ANIL SAVITA                 87
# 16  45016              MORYE MANDAR VISHWANATH RUPALI                 44
# 17  45017          / MUTHA AKANKSHA AMARCHAND SANGITA                 62
# 18  45018                  NAIK AKSHAY HEMANT HEMANGI                 57
# 19  45019                / PAGAR RIDDHI KISAN SANDHYA                 72
# 20  45020               / PANDA DEEPALI SURJA MINNOTI                 65
# 21  45021             PANDEY SHREYAS SURENDRA MADHURI                 64
# 22  45022  PASI PIYUSH SINGH UMESH CHANDRA JWALAMUKHI                 69
# 23  45023                 PATEL DARSHAN RANJIT BHAVNA                 53
# 24  45024               / PATEL DISHA DHARMESH AMPARA                 28
# 25  45025         / PATEL KANISHKA ALPESHBHAI MITABEN                 79
# 26  45026               PATHAK VAIBHAV SUSHIL KANCHAN                 55
# 27  45027               PATIL BHUSHAN BHAURAO VANDANA                 59
# 28  45028               PEDNEKAR MIHIR SANDEEP TRUPTI                 52
# 29  45029            PUSEGAONKAR SAMEER SATISH SUSHMA                 56
# 30  45030              / RAJE GAYATRI SURYAKANT ANITA                 75
# ..    ...                                         ...                ...
# 32  45032                RATH BUDDHADITYA MITALI RATH                 36
# 33  45033                RAUT PRANAV VIRENDRA PRERENA                 57
# 34  45034              / RAWAT SHIVANI SURENDER KANTI                 69
# 35  45035                   REPALE VIVEK RAMRAO SEEMA                 51
# 36  45036               / ROY SRIJITA NIRANJAN SUJATA                 45
# 37  45037                  SANKHE ARNAV KISHOR KAVITA                 63
# 38  45038                   SARAWGI AMAN DEEPAK KOMAL                 70
# 39  45039           SATPUTE PRATIK VIJAYKUMAR ARCHANA                 67
# 40  45040                  SAWANT MOHIT SUHAS NIRMALA                 61
# 41  45041                / SAXENA AKSHI ASHEEM NIRAJA                 73
# 42  45042      SHAIKH MD ABUZAR MD TAHMIL NUZHAT BANO                 72
# 43  45043                   SHARMA AJAY PAPPU SANGITA                 83
# 44  45044         SHARMA AMIT KUMAR RAMCHANDRA SHARDA                 43
# 45  45045                 / SHARMA SONAL RAJESH MEERA                 53
# 46  45046               / SHETE PRANATI SANJAY SARITA                 53
# 47  45047                / SHETTY VAISHNI ASHOKA USHA                 42
# 48  45048            SINGH AAYUSH INDRA PRATAP CHETNA                 72
# 49  45049        SONPAROTE DEEPANSHU RAJKUMAR SADHANA                 85
# 50  45050                   SORTE KUNAL YOGIRAJ SEEMA                 41
# 51  45051               SURYAWANSHI HITESH VIJAY LILA                 41
# 52  45052              TALEKAR NITISH PRAVIN SANGEETA                 72
# 53  45053                     / TANVI VINAYARAJ REKHA                 71
# 54  45054            TIKE YASH CHANDRASHEKHAR MANISHA                 21
# 55  45055                  TIWARI SATYAM DINESH MANJU                 72
# 56  45056              UPADHYAY SUDHANSHU BHARAT LATA                 49
# 57  45057                  VAGE SARTHAK GOVIND SUJATA                 65
# 58  45058             WAGHMODE AMEY SHRIKRISHNA REKHA                 75
# 59  45059              WANODE SARVESH SANJAY MANJUSHA                 58
# 60  45060              / YADAV MAMTA RAMMANOHAR VIMLA                 65
# 61  45061              / ZUTSHI DEEPALI RAJIV VANDANA                 79
#
#    DATABASE MANAGEMENT SYSTEM-TOT COMPUTER NETWORK-TOT  \
# 1                              63                   56
# 2                              75                   70
# 3                              71                   78
# 4                              55                   49
# 5                              75                   64
# 6                              71                   67
# 7                              76                   70
# 8                              77                   77
# 9                              69                   70
# 10                             66                   56
# 11                             64                   58
# 12                             52                   46
# 13                             69                   65
# 14                             71                   46
# 15                             79                   76
# 16                             66                   52
# 17                             67                   67
# 18                             70                   59
# 19                             72                   72
# 20                             78                   63
# 21                             71                   70
# 22                             69                   80
# 23                             67                   66
# 24                             60                   64
# 25                             73                   76
# 26                             64                   62
# 27                             67                   49
# 28                             65                   51
# 29                             65                   58
# 30                             70                   65
# ..                            ...                  ...
# 32                             48                   46
# 33                             57                   60
# 34                             71                   66
# 35                             49                   52
# 36                             58                   52
# 37                             67                   69
# 38                             71                   68
# 39                             66                   68
# 40                             67                   69
# 41                             69                   57
# 42                             67                   67
# 43                             74                   74
# 44                             67                   66
# 45                             77                   72
# 46                             73                   64
# 47                             60                   55
# 48                             72                   60
# 49                             72                   73
# 50                             62                   61
# 51                             59                   64
# 52                             67                   63
# 53                             68                   62
# 54                             44                   39
# 55                             60                   61
# 56                             65                   54
# 57                             68                   68
# 58                             76                   77
# 59                             70                   70
# 60                             72                   64
# 61                             67                   76
#
#    THEORY OF COMPUTER SCIENCE-TOT ADVANCE ALGORITHM-TOT TOTAL  SGPI RESULT
# 1                              68                    77   534  7.85      P
# 2                              87                    85   605  9.26      P
# 3                              76                    91   620  9.41      P
# 4                              44                    67   449  6.26      P
# 5                              60                    78   546  8.26      P
# 6                              62                    72   547  7.96      P
# 7                              72                    91   577  8.67      P
# 8                              75                    86   599  9.41      P
# 9                              63                    78   541  7.93      P
# 10                             49                    60   480  6.93      P
# 11                             70                    72   531  7.85      P
# 12                             50                    69   436  5.85      F
# 13                             57                    66   491  7.04      P
# 14                             68                    79   520  7.59      P
# 15                             75                    86   625  9.56      P
# 16                             63                    67   502  7.11      P
# 17                             59                    72   519  7.52      P
# 18                             52                    87   540  7.93      P
# 19                             71                    82   580  8.81      P
# 20                             71                    92   592  8.67      P
# 21                             61                    73   541  8.19      P
# 22                             79                    91   610  8.96      P
# 23                             57                    87   536  7.85      P
# 24                             56                    71   491   6.7      F
# 25                             67                    87   595  8.89      P
# 26                             67                    72   526   7.7      P
# 27                             60                    72   490  7.11      P
# 28                             55                    81   460  7.04      P
# 29                             50                    76   495  7.37      P
# 30                             69                    91   595  8.67      P
# ..                            ...                   ...   ...   ...    ...
# 32                             35                    55   368  4.11      F
# 33                             66                    65   501   7.3      P
# 34                             72                    74   562  8.19      P
# 35                             56                    51   417  6.15      P
# 36                              9                    66   390  4.93      F
# 37                             66                    86   545  8.04      P
# 38                             66                    83   548   8.3      P
# 39                             73                    86   560   8.3      P
# 40                             59                    81   543  8.04      P
# 41                             64                    77   546  7.93      P
# 42                             69                    87   577  8.33      P
# 43                             74                    87   613  9.11      P
# 44                             55                    75   503  7.33      P
# 45                             61                    71   546  8.19      P
# 46                             56                    74   522  7.67      P
# 47                             43                    53   445  6.26      P
# 48                             56                    78   559  8.22      P
# 49                             66                    84   593  8.89      P
# 50                             57                    72   497  7.26      P
# 51                             42                    68   458  6.44      P
# 52                             64                    79   564  8.22      P
# 53                             60                    86   549  8.19      P
# 54                             27                    49   338  3.33      F
# 55                             68                    87   549   8.3      P
# 56                             50                    76   498  7.37      P
# 57                             65                    76   541  7.93      P
# 58                             71                    90   594  9.15      P
# 59                             55                    83   551  8.19      P
# 60                             53                    86   541  8.07      P
# 61                             65                    85   577  8.74      P
#
# [61 rows x 10 columns]

# %%
# list(dfmarks.columns)

# %%
# header_later

# %%
def checkpass(x,val, i):
    if x == 'Ab':
        return 0
    return int(int(x)>val)

def checkrange(x, p,q):
    if x == 'Ab':
        return 0
    return int(p < int(str(x).strip()) and int(str(x).strip())< q)

# %%
passing = pd.DataFrame()

passing['Topper'] = dftotalmarks.loc[:,'SGPI'].apply(lambda x: int(float(x)>9.3))

for i in totalcols[2:-3]:
    passing[i.replace('TOT','PASSED')] = dftotalmarks[i].apply(lambda x :checkpass(x,40, i))


for i in totalcols[2:-3]:
    passing[i.replace('TOT','40<X<50')] = dftotalmarks[i].apply(lambda x :checkrange(x,40,50))
    passing[i.replace('TOT','50<X<60')] = dftotalmarks[i].apply(lambda x :checkrange(x,50,60))
    passing[i.replace('TOT','X>60')] = dftotalmarks[i].apply(lambda x :checkrange(x,60,100))
    
passing['SGPI < 40'] = dftotalmarks.loc[:,'SGPI'].apply(lambda x: int(float(x)<4))
passing['40 < SGPI < 50'] = dftotalmarks.loc[:,'SGPI'].apply(lambda x: int(float(x)>3.9 and float(x)<5.1))
passing['50 < SGPI < 60'] = dftotalmarks.loc[:,'SGPI'].apply(lambda x: int(float(x)>5.0 and float(x)<6.1))
passing['60 < SGPI < 70'] = dftotalmarks.loc[:,'SGPI'].apply(lambda x: int(float(x)>6.0 and float(x)<7.1))
passing['70 < SGPI < 80'] = dftotalmarks.loc[:,'SGPI'].apply(lambda x: int(float(x)>7.0 and float(x)<8.1))
passing['80 < SGPI < 90'] = dftotalmarks.loc[:,'SGPI'].apply(lambda x: int(float(x)>8.0 and float(x)<9.1))
passing['90 < SGPI < 100'] = dftotalmarks.loc[:,'SGPI'].apply(lambda x: int(float(x)>9.0 and float(x)<10.1))

passing['Perfect 100'] = dftotalmarks.loc[:,'SGPI'].apply(lambda x: int(float(x) == 10))

# %%
# type(passing)

# %%
# passing

# %%
dftotalmarks.to_excel('TotalMarks.xlsx')

# final_analysis = pd.concat([dftotalmarks,passing], axis=1)

# with pd.ExcelWriter('Analysed-Output.xlsx') as writer:  # doctest: +SKIP
#     final_analysis.to_excel(writer, sheet_name='TotalMarks')

# %%
dftotalmarks
# Out:
#      SEAT                                   NAME MICROPROCESSOR-TOT  \
# 1   45062      ACHAREKAR MANAS SANTOSH SHUBHANGI                 64
# 2   45063        ADHANGLE KUNAL RAJENDRA SUREKHA                 44
# 3   45064      AGARWAL SHIVANG DEVENDRA PRATIBHA                 12
# 4   45065   / AKSHANTULU RIDHIMA SURENDRA MALINI                 45
# 5   45066        AMBILPURE SAMEER SURENDRA MEENA                 74
# 6   45067         BAVISKAR VISHAL SHEKHAR CHHAYA                 73
# 7   45068      / BAYAS SIMRAN RAJESHSINGH VARSHA                 55
# 8   45069         BELANEKAR GIRIRAJ GANPAT PRIYA                 66
# 9   45070          BHARATI KOUSHIK PRABIR SHEELA                 47
# 10  45071            BHOGAONKAR AMEY ARUN ASMITA                 75
# 11  45072             BHOIR ABHISHEK ARJUN AMITA                 64
# 12  45073             BHOLE SOHAM PRAMOD MADHURI                  7
# 13  45074         BORKAR SHRUTI HRISHIKESH PRIYA                 25
# 14  45075       / CHAUBAL PRIYANKA SANJAY SONALI                 64
# 15  45076        DANDEKAR HARSHAD HARESH NARMADA                 41
# 16  45077         DEOLEKAR RAHUL RAJESH SANGEETA                 46
# 17  45078            DESAI KATHAN JITESH MANISHA                 56
# 18  45079            / DESAI SALONI NITIN ANJALI                 72
# 19  45080        / DHAGE PRACHI SURESH DAMAYANTI                 71
# 20  45081              DIXIT GOPESH DINESH NEETU                 39
# 21  45082            GAIKWAD ADITYA SANJAY REKHA                 44
# 22  45083                GAIKWAD RAJ ANIL ANJALI                 29
# 23  45084       / GAVASKAR DEVASHRI GIRISH GAURI                 78
# 24  45085        / GHARAT CHARMI RAJESH RAJESHRE                 42
# 25  45086  GHOSH SIDDHARTHA SAMIRENDRA SARMISTHA                 71
# 26  45087           GOPHANE SAHIL SAKHARAM KANTA                 49
# 27  45088              GORE BHAVEN VIKAS BHAVIKA                 77
# 28  45089      GUPTE SHREESHAIL SHAILENDRA SEEMA                 63
# 29  45090            INGLE SHUBHAM DEEPAK VARSHA                 44
# 30  45091       JADHAV HARSHVARDHAN SANJAY MEGHA                 10
# ..    ...                                    ...                ...
# 57  45118         MIRAJKAR ADITYA VINOD VAISHALI                 54
# 58  45119         NAIR ROHAN SREEDHARAN SHAILAJA                 51
# 59  45120     PABHAREKAR NIRANJAN MANOHAR LALITA                 42
# 60  45121              PATEL JASH MAHENDRA VEENA                 60
# 61  45122              PATEL JUNAID ASIF NASEEMA                 67
# 62  45123          PATHAN TALIF ANDALIB NAWSHEEN                 70
# 63  45124          PATIL JIGNESH SANJAY SANGEETA                 46
# 64  45125             PAWAR DEVEN VINOD VISHAKHA                 57
# 65  45126            PAWAR SHUBHAM VASANT KAVITA                 45
# 66  45127           PIMPALE RUNAL RAJENDRA NILAM                 56
# 67  45128     POTDAR PRATHMESH SUBHASH SHUBHANGI                 27
# 68  45129            RAUL MIHIR SHAILESH MADHURI                 55
# 69  45130          SANGHAVI TANISH BHAVESH NEETA                 43
# 70  45131              SAVE VIDIT VIRAJ VISHAKHA                 64
# 71  45132             SENEKAR BOBBY KISHOR NEETA                 43
# 72  45133              SHARMA YUGEEN JANAK SEEMA                 44
# 73  45134             SHETE SHUBHAM SANJAY GEETA                 52
# 74  45135    / SHIRDHANKAR DISHA MOHAN MEENAKSHI                 60
# 75  45136          SHITOLE MAYURESH SURESH SMITA                 44
# 76  45137   / SHIVSHARAN PRIYANKA BASLING AMBIKA                 20
# 77  45138              TANK NEERAJ DEEPAK KOKILA                 60
# 78  45139        TIMBADIA DHAIRYA CHETAN JASMINA                 13
# 79  45140          TIWARI SAGAR SURENDRA SHOBHNA                 11
# 80  45141             VARTAK SANMIT PANKAJ NISHA                 58
# 81  45142      / VARULE JAGRUTI NANDKUMAR SUNITA                 59
# 82  45143        VAYDANDE AJINKYA VILAS SUDHATAI                 40
# 83  45144            WANKHEDE VAIBHAV ASHOK ASHA                 30
# 84  45145             DALVI SAISH MUKUND MANDIRA                 16
# 85  45146         / RAINA ARUNDHATI RAJESH DEEPA                  6
# 86  45147         SHAH MADNI ABDUL SAMAD SHEHNAZ                 21
#
#    DATABASE MANAGEMENT SYSTEM-TOT COMPUTER NETWORK-TOT  \
# 1                              55                   43
# 2                              62                   56
# 3                              66                   43
# 4                              52                   43
# 5                              55                   62
# 6                              75                   71
# 7                              59                   50
# 8                              69                   60
# 9                              62                   51
# 10                             69                   66
# 11                             82                   73
# 12                             60                   41
# 13                             44                   48
# 14                             68                   66
# 15                             58                   52
# 16                             70                   69
# 17                             71                   73
# 18                             80                   66
# 19                             70                   76
# 20                             67                   56
# 21                             63                   58
# 22                             52                   30
# 23                             77                   61
# 24                             76                   44
# 25                             74                   68
# 26                             58                   41
# 27                             77                   64
# 28                             75                   59
# 29                             63                   66
# 30                             46                   40
# ..                            ...                  ...
# 57                             74                   68
# 58                             60                   59
# 59                             66                   41
# 60                             61                   68
# 61                             74                   61
# 62                             79                   67
# 63                             70                   54
# 64                             58                   59
# 65                             68                   56
# 66                             70                   57
# 67                             67                   47
# 68                             77                   55
# 69                             71                   42
# 70                             73                   73
# 71                             67                   43
# 72                             60                   60
# 73                             67                   47
# 74                             75                   55
# 75                             60                   46
# 76                             59                   44
# 77                             70                   57
# 78                             53                   41
# 79                             38                   21
# 80                             72                   64
# 81                             68                   62
# 82                             55                   42
# 83                             64                   48
# 84                             48                   39
# 85                             41                   15
# 86                             45                   20
#
#    THEORY OF COMPUTER SCIENCE-TOT MULTIMEDIA SYSTEM-TOT      TOTAL  SGPI  \
# 1                              48                    47        445   6.3
# 2                              47                    45        443   6.3
# 3                              25                    46        375  4.74
# 4                              55                    20        397  5.33
# 5                              50                    43        479  7.04
# 6                              75                    72        575  8.81
# 7                              40                    55        448  6.44
# 8                              49                    51        501  7.15
# 9                              45                    49        365  3.56
# 10                             64                    62        534  7.89
# 11                             67                    79        582  8.67
# 12                             43                    36        309   3.7
# 13                             42                    35        370  3.56
# 14                             55                    81        462  6.41
# 15                             40                    52        413  5.85
# 16                             61                    48        485  6.37
# 17                             56                    57        507  7.33
# 18                             65                    55        543  8.04
# 19                             49                    54        519  7.81
# 20                             48                    46        380  3.78
# 21                             51                    26        385  4.48
# 22                             40                    33        322  2.15
# 23                             75                    75        581  8.96
# 24                             42                    60        455  6.48
# 25                             53                    59        530   7.7
# 26                             43                    59  422\r\n@2  5.93
# 27                             82                    62        573  8.74
# 28                             63                    52        518  7.59
# 29                             45                    58        479  6.85
# 30                             21                    20        289  2.41
# ..                            ...                   ...        ...   ...
# 57                             54                    70        525  7.63
# 58                             62                    65        483  7.11
# 59                             55                    51        434  6.04
# 60                             50                    48        447   6.7
# 61                             48                    65        499  7.22
# 62                             68                    82        559  8.37
# 63                             40                    64        447  6.44
# 64                             61                    64        491  7.07
# 65                             55                    64        449  6.52
# 66                             54                    59        489  7.04
# 67                             53                    58        443  5.89
# 68                             65                    68        536  7.78
# 69                             66                    51        471   6.7
# 70                             72                    73        565  8.33
# 71                             49                    50        400  5.19
# 72                             59                    62        461   6.7
# 73                             61                    55        477  6.96
# 74                             61                    57        502  7.48
# 75                             46                    52        432  6.22
# 76                             52                    61        431  5.74
# 77                             58                    53        492  7.33
# 78                             39                    30        328  2.85
# 79                             38                    41        287  1.78
# 80                             68                    61        507  7.37
# 81                             56                    50        485  6.96
# 82                             52                    54        426  6.11
# 83                             56                    49        420  5.48
# 84                             56                    43        336  3.52
# 85                             27                    19        242  1.85
# 86                             40                    45        318  3.48
#
#    RESULT
# 1       P
# 2       P
# 3       F
# 4       F
# 5       P
# 6       P
# 7       P
# 8       P
# 9       F
# 10      P
# 11      P
# 12      F
# 13      F
# 14      F
# 15      P
# 16      F
# 17      P
# 18      P
# 19      P
# 20      F
# 21      F
# 22      F
# 23      P
# 24      P
# 25      P
# 26      P
# 27      P
# 28      P
# 29      P
# 30      F
# ..    ...
# 57      P
# 58      P
# 59      P
# 60      P
# 61      P
# 62      P
# 63      P
# 64      P
# 65      P
# 66      P
# 67      F
# 68      P
# 69      P
# 70      P
# 71      F
# 72      P
# 73      P
# 74      P
# 75      P
# 76      F
# 77      P
# 78      F
# 79      F
# 80      P
# 81      P
# 82      P
# 83      F
# 84      F
# 85      F
# 86      F
#
# [86 rows x 10 columns]
