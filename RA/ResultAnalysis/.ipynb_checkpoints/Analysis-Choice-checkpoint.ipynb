# %%
#LIBRARIES
import pandas as pd
import matplotlib.pyplot as plt

# %%
############################################################

# READ FILE + DROP NULL COLUMNS
# original_file = pd.read_excel('data/Check.xlsx')
# original_file = pd.read_excel('data/Result-Format1.xlsx')
# original_file = pd.read_excel('data/Result-Format2.xls')
# original_file = pd.read_excel('data/Result-Format3-Elective.xls')
original_file = pd.read_excel('data/Result-Format3-Elective2.xls')

# remove rows wiht all na
original_file.dropna(how="all", inplace=True)

# remove redundant column
original_file.drop(['Unnamed: 1'], axis=1, inplace=True)
original_file = original_file.iloc[:,:-1]

# scrap part of original dataframe
original_file1 = original_file.iloc[3:,:]
original_file1 = original_file1.dropna(axis='columns', how='all')

# regenerating old file for selected columns only
original_file = original_file.loc[:,original_file1.columns]

############################################################

# %%
# original_file.head()

# %%
############################################################

# Working with Header for further use
curr_header = [str(i) for i in original_file.iloc[2,:].values]
add_details = [str(i) for i in original_file.iloc[3,:].values]

header = ['SEAT', 'TOTAL', 'SGPI', 'RESULT']

for i in range(1, len(curr_header)-4):
    j = i
    while curr_header[j] == 'nan':
        j = j - 1
    header.insert(-3,(curr_header[j].strip()+'-'+add_details[i].strip()))

header_later = header.copy()
header_later.insert(1, 'NAME')

############################################################

# %%
# header

# %%
############################################################

# Creating a list of subject names and codes and mapping them
subjectlist = [i for i in curr_header if i != 'nan']
subjectcode = [i for i in original_file.iloc[1,:].values[1:-4] if str(i) != 'nan']
subjectcodes = dict(zip(subjectcode,subjectlist))

############################################################

# %%
# subjectcodes

# %%
############################################################

# Creating a dataframe to work on
df = original_file1.iloc[:,:]
df = df.loc[df['Unnamed: 2'].isna() == False]

# removing CGPA column
df = df.iloc[:,:-1]

df.columns = header

df = df.iloc[3:,:]

# dataframe to store marks
dfmarks = df.iloc[::2]

# dataframe that stores names
dfnames = df.iloc[1::2]

# adding names to the marks dataframe
dfmarks = dfmarks.copy()
dfmarks['NAME'] = dfnames.loc[:, 'SEAT'].values
dfmarks = dfmarks.loc[:,header_later]

dfmarks.index = pd.RangeIndex(1,len(dfmarks.index)+1)


############################################################

# %%
# len(original_file1.columns)

# %%
dfmarks
# Out:
#      SEAT                                   NAME MICROPROCESSOR-ESE  \
# 1   45062      ACHAREKAR MANAS SANTOSH SHUBHANGI                 55
# 2   45063        ADHANGLE KUNAL RAJENDRA SUREKHA                 35
# 3   45064      AGARWAL SHIVANG DEVENDRA PRATIBHA                11F
# 4   45065   / AKSHANTULU RIDHIMA SURENDRA MALINI                36E
# 5   45066        AMBILPURE SAMEER SURENDRA MEENA                 62
# 6   45067         BAVISKAR VISHAL SHEKHAR CHHAYA                 58
# 7   45068      / BAYAS SIMRAN RAJESHSINGH VARSHA                 45
# 8   45069         BELANEKAR GIRIRAJ GANPAT PRIYA                 54
# 9   45070          BHARATI KOUSHIK PRABIR SHEELA                42E
# 10  45071            BHOGAONKAR AMEY ARUN ASMITA                 60
# 11  45072             BHOIR ABHISHEK ARJUN AMITA                 50
# 12  45073             BHOLE SOHAM PRAMOD MADHURI                03F
# 13  45074         BORKAR SHRUTI HRISHIKESH PRIYA                19F
# 14  45075       / CHAUBAL PRIYANKA SANJAY SONALI                55E
# 15  45076        DANDEKAR HARSHAD HARESH NARMADA                 32
# 16  45077         DEOLEKAR RAHUL RAJESH SANGEETA                41E
# 17  45078            DESAI KATHAN JITESH MANISHA                 45
# 18  45079            / DESAI SALONI NITIN ANJALI                 57
# 19  45080        / DHAGE PRACHI SURESH DAMAYANTI                 59
# 20  45081              DIXIT GOPESH DINESH NEETU                34E
# 21  45082            GAIKWAD ADITYA SANJAY REKHA                40E
# 22  45083                GAIKWAD RAJ ANIL ANJALI                21F
# 23  45084       / GAVASKAR DEVASHRI GIRISH GAURI                 64
# 24  45085       / GHARAT CHARMI RAJESH RAJESHREE                 32
# 25  45086  GHOSH SIDDHARTHA SAMIRENDRA SARMISTHA                 57
# 26  45087           GOPHANE SAHIL SAKHARAM KANTA                 41
# 27  45088              GORE BHAVEN VIKAS BHAVIKA                 61
# 28  45089      GUPTE SHREESHAIL SHAILENDRA SEEMA                 48
# 29  45090            INGLE SHUBHAM DEEPAK VARSHA                 34
# 30  45091       JADHAV HARSHVARDHAN SANJAY MEGHA                05F
# ..    ...                                    ...                ...
# 57  45118         MIRAJKAR ADITYA VINOD VAISHALI                 42
# 58  45119         NAIR ROHAN SREEDHARAN SHAILAJA                 40
# 59  45120     PABHAREKAR NIRANJAN MANOHAR LALITA                 32
# 60  45121              PATEL JASH MAHENDRA VEENA                 52
# 61  45122              PATEL JUNAID ASIF NASEEMA                 57
# 62  45123          PATHAN TALIF ANDALIB NAWSHEEN                 56
# 63  45124          PATIL JIGNESH SANJAY SANGEETA                 34
# 64  45125             PAWAR DEVEN VINOD VISHAKHA                 40
# 65  45126            PAWAR SHUBHAM VASANT KAVITA                 34
# 66  45127           PIMPALE RUNAL RAJENDRA NILAM                 44
# 67  45128     POTDAR PRATHMESH SUBHASH SHUBHANGI                18F
# 68  45129            RAUL MIHIR SHAILESH MADHURI                 42
# 69  45130          SANGHAVI TANISH BHAVESH NEETA                 32
# 70  45131              SAVE VIDIT VIRAJ VISHAKHA                 53
# 71  45132             SENEKAR BOBBY KISHOR NEETA                32E
# 72  45133              SHARMA YUGEEN JANAK SEEMA                 32
# 73  45134             SHETE SHUBHAM SANJAY GEETA                 42
# 74  45135    / SHIRDHANKAR DISHA MOHAN MEENAKSHI                 50
# 75  45136          SHITOLE MAYURESH SURESH SMITA                 34
# 76  45137   / SHIVSHARAN PRIYANKA BASLING AMBIKA                11F
# 77  45138              TANK NEERAJ DEEPAK KOKILA                 47
# 78  45139        TIMBADIA DHAIRYA CHETAN JASMINA                09F
# 79  45140          TIWARI SAGAR SURENDRA SHOBHNA                05F
# 80  45141             VARTAK SANMIT PANKAJ NISHA                 49
# 81  45142      / VARULE JAGRUTI NANDKUMAR SUNITA                 50
# 82  45143        VAYDANDE AJINKYA VILAS SUDHATAI                 32
# 83  45144            WANKHEDE VAIBHAV ASHOK ASHA                22F
# 84  45145             DALVI SAISH MUKUND MANDIRA                10F
# 85  45146         / RAINA ARUNDHATI RAJESH DEEPA                02F
# 86  45147         SHAH MADNI ABDUL SAMAD SHEHNAZ                13F
#
#    MICROPROCESSOR-IA MICROPROCESSOR-TOT DATABASE MANAGEMENT SYSTEM-ESE  \
# 1                 09                 64                             45
# 2                 09                 44                             52
# 3                01F                 12                            53E
# 4                09E                 45                            44E
# 5                 12                 74                             45
# 6                 15                 73                             60
# 7                 10                 55                             49
# 8                 12                 66                             56
# 9                05F                 47                            52E
# 10                15                 75                             53
# 11                14                 64                             65
# 12               04F                  7                            49E
# 13               06F                 25                            35E
# 14               09E                 64                            54E
# 15                09                 41                             45
# 16               05F                 46                            57E
# 17                11                 56                             55
# 18                15                 72                             66
# 19                12                 71                             58
# 20               05F                 39                            59E
# 21               04F                 44                            54E
# 22               08E                 29                            43E
# 23                14                 78                             61
# 24                10                 42                             61
# 25                14                 71                             61
# 26                08                 49                             48
# 27                16                 77                             59
# 28                15                 63                             58
# 29                10                 44                             51
# 30               05F                 10                            39E
# ..               ...                ...                            ...
# 57                12                 54                             60
# 58                11                 51                             49
# 59                10                 42                             55
# 60                08                 60                             50
# 61                10                 67                             60
# 62                14                 70                             62
# 63                12                 46                             55
# 64                17                 57                             45
# 65                11                 45                             55
# 66                12                 56                             56
# 67               09E                 27                            54E
# 68                13                 55                             61
# 69                11                 43                             58
# 70                11                 64                             58
# 71               11E                 43                            55E
# 72                12                 44                             49
# 73                10                 52                             55
# 74                10                 60                             63
# 75                10                 44                             47
# 76               09E                 20                            45E
# 77                13                 60                             55
# 78               04F                 13                            43E
# 79               06F                 11                            32E
# 80                09                 58                             57
# 81                09                 59                             55
# 82                08                 40                             45
# 83               08E                 30                            51E
# 84               06F                 16                            38E
# 85               04F                  6                            32E
# 86               08E                 21                            35E
#
#    DATABASE MANAGEMENT SYSTEM-IA DATABASE MANAGEMENT SYSTEM-TOT  \
# 1                             10                             55
# 2                             10                             62
# 3                            13E                             66
# 4                            08E                             52
# 5                             10                             55
# 6                             15                             75
# 7                             10                             59
# 8                             13                             69
# 9                            10E                             62
# 10                            16                             69
# 11                            17                             82
# 12                           11E                             60
# 13                           09E                             44
# 14                           14E                             68
# 15                            13                             58
# 16                           13E                             70
# 17                            16                             71
# 18                            14                             80
# 19                            12                             70
# 20                           08E                             67
# 21                           09E                             63
# 22                           09E                             52
# 23                            16                             77
# 24                            15                             76
# 25                            13                             74
# 26                            10                             58
# 27                            18                             77
# 28                            17                             75
# 29                            12                             63
# 30                           07F                             46
# ..                           ...                            ...
# 57                            14                             74
# 58                            11                             60
# 59                            11                             66
# 60                            11                             61
# 61                            14                             74
# 62                            17                             79
# 63                            15                             70
# 64                            13                             58
# 65                            13                             68
# 66                            14                             70
# 67                           13E                             67
# 68                            16                             77
# 69                            13                             71
# 70                            15                             73
# 71                           12E                             67
# 72                            11                             60
# 73                            12                             67
# 74                            12                             75
# 75                            13                             60
# 76                           14E                             59
# 77                            15                             70
# 78                           10E                             53
# 79                           06F                             38
# 80                            15                             72
# 81                            13                             68
# 82                            10                             55
# 83                           13E                             64
# 84                           10E                             48
# 85                           09E                             41
# 86                           10E                             45
#
#    COMPUTER NETWORK-ESE COMPUTER NETWORK-IA  ...  \
# 1                    32                  11  ...
# 2                    46                  10  ...
# 3                   32E                 11E  ...
# 4                   32E                 11E  ...
# 5                    51                  11  ...
# 6                    53                  18  ...
# 7                    40                  10  ...
# 8                    42                  18  ...
# 9                   46E            05E\r\n!  ...
# 10                   51                  15  ...
# 11                   57                  16  ...
# 12                  33E                 08E  ...
# 13                  38E                 10E  ...
# 14                  54E                 12E  ...
# 15                   44                  08  ...
# 16                  51E                 18E  ...
# 17                   57                  16  ...
# 18                   50                  16  ...
# 19                   60                  16  ...
# 20                  44E                 12E  ...
# 21                  49E                 09E  ...
# 22                  22F                 08E  ...
# 23                   42                  19  ...
# 24                   32                  12  ...
# 25                   52                  16  ...
# 26                   33                  08  ...
# 27                   46                  18  ...
# 28                   42                  17  ...
# 29                   50                  16  ...
# 30                  32E                 08E  ...
# ..                  ...                 ...  ...
# 57                   49                  19  ...
# 58                   50                  09  ...
# 59                   33                  08  ...
# 60                   59                  09  ...
# 61                   50                  11  ...
# 62                   55                  12  ...
# 63                   46                  08  ...
# 64                   47                  12  ...
# 65                   44                  12  ...
# 66                   46                  11  ...
# 67                  37E                 10E  ...
# 68                   41                  14  ...
# 69                   33                  09  ...
# 70                   58                  15  ...
# 71                  32E                 11E  ...
# 72                   46                  14  ...
# 73                   38                  09  ...
# 74                   38                  17  ...
# 75                   37                  09  ...
# 76                  33E                 11E  ...
# 77                   42                  15  ...
# 78                  33E                 08E  ...
# 79                  13F                 08E  ...
# 80                   51                  13  ...
# 81                   52                  10  ...
# 82                   32                  10  ...
# 83                  39E                 09E  ...
# 84                  32E                 07F  ...
# 85                  10F                 05F  ...
# 86                  14F                 06F  ...
#
#    DATABASE & INFORMATION SYSTEM LAB-PR OR  \
# 1                                       18
# 2                                       16
# 3                                      20E
# 4                                      18E
# 5                                       16
# 6                                       22
# 7                                       18
# 8                                       19
# 9                                      12E
# 10                                      18
# 11                                      23
# 12                                     14E
# 13                                     17E
# 14                                     13E
# 15                                      18
# 16                                     20E
# 17                                      20
# 18                                      23
# 19                                      18
# 20                                     17E
# 21                                     21E
# 22                                     18E
# 23                                      23
# 24                                      20
# 25                                      19
# 26                                      17
# 27                                      19
# 28                                      23
# 29                                      19
# 30                                     18E
# ..                                     ...
# 57                                      24
# 58                                      17
# 59                                      19
# 60                                      12
# 61                                      17
# 62                                      21
# 63                                      18
# 64                                      18
# 65                                      16
# 66                                      18
# 67                                     19E
# 68                                      21
# 69                                      20
# 70                                      19
# 71                                     14E
# 72                                      19
# 73                                      18
# 74                                      17
# 75                                      19
# 76                                     18E
# 77                                      19
# 78                                     18E
# 79                                     12E
# 80                                      19
# 81                                      19
# 82                                      18
# 83                                     18E
# 84                                     13E
# 85                                     15E
# 86                                     12E
#
#    DATABASE & INFORMATION SYSTEM LAB-TW DATABASE & INFORMATION SYSTEM LAB-TOT  \
# 1                                    19                                    37
# 2                                    16                                    32
# 3                                   18E                                    38
# 4                                   19E                                    37
# 5                                    21                                    37
# 6                                    21                                    43
# 7                                    19                                    37
# 8                                    20                                    39
# 9                                   10E                                    22
# 10                                   19                                    37
# 11                                   23                                    46
# 12                                  12E                                    26
# 13                                  18E                                    35
# 14                                  13E                                    26
# 15                                   18                                    36
# 16                                  18E                                    38
# 17                                   22                                    42
# 18                                   22                                    45
# 19                                   20                                    38
# 20                                  13E                                    30
# 21                                  12E                                    33
# 22                                  14E                                    32
# 23                                   23                                    46
# 24                                   17                                    37
# 25                                   21                                    40
# 26                                   19                                    36
# 27                                   21                                    40
# 28                                   20                                    43
# 29                                   19                                    38
# 30                                  16E                                    34
# ..                                  ...                                   ...
# 57                                   20                                    44
# 58                                   17                                    34
# 59                                   18                                    37
# 60                                   12                                    24
# 61                                   17                                    34
# 62                                   19                                    40
# 63                                   19                                    37
# 64                                   18                                    36
# 65                                   17                                    33
# 66                                   19                                    37
# 67                                  18E                                    37
# 68                                   20                                    41
# 69                                   19                                    39
# 70                                   20                                    39
# 71                                  15E                                    29
# 72                                   17                                    36
# 73                                   16                                    34
# 74                                   21                                    38
# 75                                   20                                    39
# 76                                  19E                                    37
# 77                                   20                                    39
# 78                                  17E                                    35
# 79                                  10E                                    22
# 80                                   18                                    37
# 81                                   19                                    38
# 82                                   16                                    34
# 83                                  17E                                    35
# 84                                  13E                                    26
# 85                                  14E                                    29
# 86                                  12E                                    24
#
#    WEB DESIGN LAB-PR OR WEB DESIGN LAB-TW WEB DESIGN LAB-TOT  \
# 1                    18                21                 39
# 2                    20                19                 39
# 3                   17E               23E                 40
# 4                   14E               21E                 35
# 5                    20                22                 42
# 6                    20                24                 44
# 7                    14                21                 35
# 8                    15                22                 37
# 9                   06F               11E                 17
# 10                   23                23                 46
# 11                   18                24                 42
# 12                  12E               18E                 30
# 13                  18E               21E                 39
# 14                  06F               14E                 20
# 15                   11                17                 28
# 16                  21E               22E                 43
# 17                   16                21                 37
# 18                   16                20                 36
# 19                   22                21                 43
# 20                  08F               12E                 20
# 21                  13E               15E                 28
# 22                  07F               15E                 22
# 23                   21                19                 40
# 24                   17                23                 40
# 25                   19                19                 38
# 26                   14                19                 33
# 27                   18                21                 39
# 28                   18                19                 37
# 29                   18                22                 40
# 30                  18E               15E                 33
# ..                  ...               ...                ...
# 57                   19                20                 39
# 58                   20                19                 39
# 59                   12                18                 30
# 60                   17                17                 34
# 61                   17                18                 35
# 62                   17                20                 37
# 63                   13                17                 30
# 64                   18                21                 39
# 65                   16                16                 32
# 66                   18                18                 36
# 67                  20E               19E                 39
# 68                   23                21                 44
# 69                   19                20                 39
# 70                   22                20                 42
# 71                  06F               13E                 19
# 72                   12                19                 31
# 73                   23                20                 43
# 74                   12                19                 31
# 75                   19                18                 37
# 76                  18E               21E                 39
# 77                   19                23                 42
# 78                  06F               15E                 21
# 79                  08F               18E                 26
# 80                   18                18                 36
# 81                   11                21                 32
# 82                   19                21                 40
# 83                  13E               17E                 30
# 84                  06F               15E                 21
# 85                  06F               11E                 17
# 86                  07F               15E                 22
#
#    BUSINESS COMMUNICATION & ETHICS-TW      TOTAL  SGPI RESULT
# 1                                  42        445   6.3      P
# 2                                  38        443   6.3      P
# 3                                 40E        375  4.74      F
# 4                                 40E        397  5.33      F
# 5                                  40        479  7.04      P
# 6                                  41        575  8.81      P
# 7                                  42        448  6.44      P
# 8                                  44        501  7.15      P
# 9                                 35E        365  3.56      F
# 10                                 42        534  7.89      P
# 11                                 42        582  8.67      P
# 12                                35E        309   3.7      F
# 13                                41E        370  3.56      F
# 14                                34E        462  6.41      F
# 15                                 40        413  5.85      P
# 16                                40E        485  6.37      F
# 17                                 43        507  7.33      P
# 18                                 44        543  8.04      P
# 19                                 43        519  7.81      P
# 20                                38E        380  3.78      F
# 21                                35E        385  4.48      F
# 22                                36E        322  2.15      F
# 23                                 40        581  8.96      P
# 24                                 39        455  6.48      P
# 25                                 42        530   7.7      P
# 26                                 40  422\r\n@2  5.93      P
# 27                                 44        573  8.74      P
# 28                                 42        518  7.59      P
# 29                                 44        479  6.85      P
# 30                                39E        289  2.41      F
# ..                                ...        ...   ...    ...
# 57                                 39        525  7.63      P
# 58                                 38        483  7.11      P
# 59                                 37        434  6.04      P
# 60                                 40        447   6.7      P
# 61                                 42        499  7.22      P
# 62                                 38        559  8.37      P
# 63                                 39        447  6.44      P
# 64                                 38        491  7.07      P
# 65                                 38        449  6.52      P
# 66                                 40        489  7.04      P
# 67                                40E        443  5.89      F
# 68                                 42        536  7.78      P
# 69                                 43        471   6.7      P
# 70                                43         565  8.33      P
# 71                                37E        400  5.19      F
# 72                                 42        461   6.7      P
# 73                                 42        477  6.96      P
# 74                                 44        502  7.48      P
# 75                                 40        432  6.22      P
# 76                                39E        431  5.74      F
# 77                                 40        492  7.33      P
# 78                                35E        328  2.85      F
# 79                                36E        287  1.78      F
# 80                                 38        507  7.37      P
# 81                                 39        485  6.96      P
# 82                                 39        426  6.11      P
# 83                                43E        420  5.48      F
# 84                                39E        336  3.52      F
# 85                                39E        242  1.85      F
# 86                                43E        318  3.48      F
#
# [86 rows x 33 columns]

# %%
############################################################

# to clean the columns

def clean(x):
    if x == 'Ab':
        return int(0)
    ########################
    ## Might need changes
    if '\r' in str(x):
        x = x[:x.index('\r')]
    ########################
    x = list(str(x))
    if x[-1] == 'E' or  x[-1] == 'F':
        return "".join(x[:-1]).strip()
    else:
        return "".join(x)
    
for i in range(1,len(dfmarks.columns)-3):
    dfmarks.iloc[:,i] = dfmarks.iloc[:,i].apply(clean)
    
############################################################

# %%
# subjectlist

# %%
############################################################

# fetching the total columns

labstr = subjectcode[-1][:3]
totalsubs = []
for k,v in subjectcodes.items():
    if labstr not in k:
        totalsubs.append(v)
if len(totalsubs) == 0:
    totalsubs = subjectlist.copy()
df_header = list(dfmarks.columns)
totalcols = df_header[:2] + [str(i.strip()+'-TOT') for i in totalsubs] + df_header[-3:]
# totalcols

############################################################

# %%
# totalcols

# %%
############################################################

# TOTAL MARKS DATAFRAME

dftotalmarks = dfmarks[totalcols]

dftotalmarks = dftotalmarks.loc[:,~dftotalmarks.columns.duplicated()]
############################################################

# %%
dftotalmarks
# Out:
#      SEAT                                   NAME MICROPROCESSOR-TOT  \
# 1   45062      ACHAREKAR MANAS SANTOSH SHUBHANGI                 64
# 2   45063        ADHANGLE KUNAL RAJENDRA SUREKHA                 44
# 3   45064      AGARWAL SHIVANG DEVENDRA PRATIBHA                 12
# 4   45065   / AKSHANTULU RIDHIMA SURENDRA MALINI                 45
# 5   45066        AMBILPURE SAMEER SURENDRA MEENA                 74
# 6   45067         BAVISKAR VISHAL SHEKHAR CHHAYA                 73
# 7   45068      / BAYAS SIMRAN RAJESHSINGH VARSHA                 55
# 8   45069         BELANEKAR GIRIRAJ GANPAT PRIYA                 66
# 9   45070          BHARATI KOUSHIK PRABIR SHEELA                 47
# 10  45071            BHOGAONKAR AMEY ARUN ASMITA                 75
# 11  45072             BHOIR ABHISHEK ARJUN AMITA                 64
# 12  45073             BHOLE SOHAM PRAMOD MADHURI                  7
# 13  45074         BORKAR SHRUTI HRISHIKESH PRIYA                 25
# 14  45075       / CHAUBAL PRIYANKA SANJAY SONALI                 64
# 15  45076        DANDEKAR HARSHAD HARESH NARMADA                 41
# 16  45077         DEOLEKAR RAHUL RAJESH SANGEETA                 46
# 17  45078            DESAI KATHAN JITESH MANISHA                 56
# 18  45079            / DESAI SALONI NITIN ANJALI                 72
# 19  45080        / DHAGE PRACHI SURESH DAMAYANTI                 71
# 20  45081              DIXIT GOPESH DINESH NEETU                 39
# 21  45082            GAIKWAD ADITYA SANJAY REKHA                 44
# 22  45083                GAIKWAD RAJ ANIL ANJALI                 29
# 23  45084       / GAVASKAR DEVASHRI GIRISH GAURI                 78
# 24  45085        / GHARAT CHARMI RAJESH RAJESHRE                 42
# 25  45086  GHOSH SIDDHARTHA SAMIRENDRA SARMISTHA                 71
# 26  45087           GOPHANE SAHIL SAKHARAM KANTA                 49
# 27  45088              GORE BHAVEN VIKAS BHAVIKA                 77
# 28  45089      GUPTE SHREESHAIL SHAILENDRA SEEMA                 63
# 29  45090            INGLE SHUBHAM DEEPAK VARSHA                 44
# 30  45091       JADHAV HARSHVARDHAN SANJAY MEGHA                 10
# ..    ...                                    ...                ...
# 57  45118         MIRAJKAR ADITYA VINOD VAISHALI                 54
# 58  45119         NAIR ROHAN SREEDHARAN SHAILAJA                 51
# 59  45120     PABHAREKAR NIRANJAN MANOHAR LALITA                 42
# 60  45121              PATEL JASH MAHENDRA VEENA                 60
# 61  45122              PATEL JUNAID ASIF NASEEMA                 67
# 62  45123          PATHAN TALIF ANDALIB NAWSHEEN                 70
# 63  45124          PATIL JIGNESH SANJAY SANGEETA                 46
# 64  45125             PAWAR DEVEN VINOD VISHAKHA                 57
# 65  45126            PAWAR SHUBHAM VASANT KAVITA                 45
# 66  45127           PIMPALE RUNAL RAJENDRA NILAM                 56
# 67  45128     POTDAR PRATHMESH SUBHASH SHUBHANGI                 27
# 68  45129            RAUL MIHIR SHAILESH MADHURI                 55
# 69  45130          SANGHAVI TANISH BHAVESH NEETA                 43
# 70  45131              SAVE VIDIT VIRAJ VISHAKHA                 64
# 71  45132             SENEKAR BOBBY KISHOR NEETA                 43
# 72  45133              SHARMA YUGEEN JANAK SEEMA                 44
# 73  45134             SHETE SHUBHAM SANJAY GEETA                 52
# 74  45135    / SHIRDHANKAR DISHA MOHAN MEENAKSHI                 60
# 75  45136          SHITOLE MAYURESH SURESH SMITA                 44
# 76  45137   / SHIVSHARAN PRIYANKA BASLING AMBIKA                 20
# 77  45138              TANK NEERAJ DEEPAK KOKILA                 60
# 78  45139        TIMBADIA DHAIRYA CHETAN JASMINA                 13
# 79  45140          TIWARI SAGAR SURENDRA SHOBHNA                 11
# 80  45141             VARTAK SANMIT PANKAJ NISHA                 58
# 81  45142      / VARULE JAGRUTI NANDKUMAR SUNITA                 59
# 82  45143        VAYDANDE AJINKYA VILAS SUDHATAI                 40
# 83  45144            WANKHEDE VAIBHAV ASHOK ASHA                 30
# 84  45145             DALVI SAISH MUKUND MANDIRA                 16
# 85  45146         / RAINA ARUNDHATI RAJESH DEEPA                  6
# 86  45147         SHAH MADNI ABDUL SAMAD SHEHNAZ                 21
#
#    DATABASE MANAGEMENT SYSTEM-TOT COMPUTER NETWORK-TOT  \
# 1                              55                   43
# 2                              62                   56
# 3                              66                   43
# 4                              52                   43
# 5                              55                   62
# 6                              75                   71
# 7                              59                   50
# 8                              69                   60
# 9                              62                   51
# 10                             69                   66
# 11                             82                   73
# 12                             60                   41
# 13                             44                   48
# 14                             68                   66
# 15                             58                   52
# 16                             70                   69
# 17                             71                   73
# 18                             80                   66
# 19                             70                   76
# 20                             67                   56
# 21                             63                   58
# 22                             52                   30
# 23                             77                   61
# 24                             76                   44
# 25                             74                   68
# 26                             58                   41
# 27                             77                   64
# 28                             75                   59
# 29                             63                   66
# 30                             46                   40
# ..                            ...                  ...
# 57                             74                   68
# 58                             60                   59
# 59                             66                   41
# 60                             61                   68
# 61                             74                   61
# 62                             79                   67
# 63                             70                   54
# 64                             58                   59
# 65                             68                   56
# 66                             70                   57
# 67                             67                   47
# 68                             77                   55
# 69                             71                   42
# 70                             73                   73
# 71                             67                   43
# 72                             60                   60
# 73                             67                   47
# 74                             75                   55
# 75                             60                   46
# 76                             59                   44
# 77                             70                   57
# 78                             53                   41
# 79                             38                   21
# 80                             72                   64
# 81                             68                   62
# 82                             55                   42
# 83                             64                   48
# 84                             48                   39
# 85                             41                   15
# 86                             45                   20
#
#    THEORY OF COMPUTER SCIENCE-TOT MULTIMEDIA SYSTEM-TOT      TOTAL  SGPI  \
# 1                              48                    47        445   6.3
# 2                              47                    45        443   6.3
# 3                              25                    46        375  4.74
# 4                              55                    20        397  5.33
# 5                              50                    43        479  7.04
# 6                              75                    72        575  8.81
# 7                              40                    55        448  6.44
# 8                              49                    51        501  7.15
# 9                              45                    49        365  3.56
# 10                             64                    62        534  7.89
# 11                             67                    79        582  8.67
# 12                             43                    36        309   3.7
# 13                             42                    35        370  3.56
# 14                             55                    81        462  6.41
# 15                             40                    52        413  5.85
# 16                             61                    48        485  6.37
# 17                             56                    57        507  7.33
# 18                             65                    55        543  8.04
# 19                             49                    54        519  7.81
# 20                             48                    46        380  3.78
# 21                             51                    26        385  4.48
# 22                             40                    33        322  2.15
# 23                             75                    75        581  8.96
# 24                             42                    60        455  6.48
# 25                             53                    59        530   7.7
# 26                             43                    59  422\r\n@2  5.93
# 27                             82                    62        573  8.74
# 28                             63                    52        518  7.59
# 29                             45                    58        479  6.85
# 30                             21                    20        289  2.41
# ..                            ...                   ...        ...   ...
# 57                             54                    70        525  7.63
# 58                             62                    65        483  7.11
# 59                             55                    51        434  6.04
# 60                             50                    48        447   6.7
# 61                             48                    65        499  7.22
# 62                             68                    82        559  8.37
# 63                             40                    64        447  6.44
# 64                             61                    64        491  7.07
# 65                             55                    64        449  6.52
# 66                             54                    59        489  7.04
# 67                             53                    58        443  5.89
# 68                             65                    68        536  7.78
# 69                             66                    51        471   6.7
# 70                             72                    73        565  8.33
# 71                             49                    50        400  5.19
# 72                             59                    62        461   6.7
# 73                             61                    55        477  6.96
# 74                             61                    57        502  7.48
# 75                             46                    52        432  6.22
# 76                             52                    61        431  5.74
# 77                             58                    53        492  7.33
# 78                             39                    30        328  2.85
# 79                             38                    41        287  1.78
# 80                             68                    61        507  7.37
# 81                             56                    50        485  6.96
# 82                             52                    54        426  6.11
# 83                             56                    49        420  5.48
# 84                             56                    43        336  3.52
# 85                             27                    19        242  1.85
# 86                             40                    45        318  3.48
#
#    RESULT
# 1       P
# 2       P
# 3       F
# 4       F
# 5       P
# 6       P
# 7       P
# 8       P
# 9       F
# 10      P
# 11      P
# 12      F
# 13      F
# 14      F
# 15      P
# 16      F
# 17      P
# 18      P
# 19      P
# 20      F
# 21      F
# 22      F
# 23      P
# 24      P
# 25      P
# 26      P
# 27      P
# 28      P
# 29      P
# 30      F
# ..    ...
# 57      P
# 58      P
# 59      P
# 60      P
# 61      P
# 62      P
# 63      P
# 64      P
# 65      P
# 66      P
# 67      F
# 68      P
# 69      P
# 70      P
# 71      F
# 72      P
# 73      P
# 74      P
# 75      P
# 76      F
# 77      P
# 78      F
# 79      F
# 80      P
# 81      P
# 82      P
# 83      F
# 84      F
# 85      F
# 86      F
#
# [86 rows x 10 columns]

# %%
# list(dfmarks.columns)

# %%
# header_later

# %%
def checkpass(x,val, i):
    if x == 'Ab':
        return 0
    return int(int(x)>val)

def checkrange(x, p,q):
    if x == 'Ab':
        return 0
    return int(p < int(str(x).strip()) and int(str(x).strip())< q)

# %%
passing = pd.DataFrame()

passing['Topper'] = dftotalmarks.loc[:,'SGPI'].apply(lambda x: int(float(x)>9.3))

for i in totalcols[2:-3]:
    passing[i.replace('TOT','PASSED')] = dftotalmarks[i].apply(lambda x :checkpass(x,40, i))


for i in totalcols[2:-3]:
    passing[i.replace('TOT','40<X<50')] = dftotalmarks[i].apply(lambda x :checkrange(x,40,50))
    passing[i.replace('TOT','50<X<60')] = dftotalmarks[i].apply(lambda x :checkrange(x,50,60))
    passing[i.replace('TOT','X>60')] = dftotalmarks[i].apply(lambda x :checkrange(x,60,100))
    
passing['SGPI < 40'] = dftotalmarks.loc[:,'SGPI'].apply(lambda x: int(float(x)<4))
passing['40 < SGPI < 50'] = dftotalmarks.loc[:,'SGPI'].apply(lambda x: int(float(x)>3.9 and float(x)<5.1))
passing['50 < SGPI < 60'] = dftotalmarks.loc[:,'SGPI'].apply(lambda x: int(float(x)>5.0 and float(x)<6.1))
passing['60 < SGPI < 70'] = dftotalmarks.loc[:,'SGPI'].apply(lambda x: int(float(x)>6.0 and float(x)<7.1))
passing['70 < SGPI < 80'] = dftotalmarks.loc[:,'SGPI'].apply(lambda x: int(float(x)>7.0 and float(x)<8.1))
passing['80 < SGPI < 90'] = dftotalmarks.loc[:,'SGPI'].apply(lambda x: int(float(x)>8.0 and float(x)<9.1))
passing['90 < SGPI < 100'] = dftotalmarks.loc[:,'SGPI'].apply(lambda x: int(float(x)>9.0 and float(x)<10.1))

passing['Perfect 100'] = dftotalmarks.loc[:,'SGPI'].apply(lambda x: int(float(x) == 10))

# %%
# type(passing)

# %%
# passing

# %%
# dftotalmarks.to_excel('Analysis-2.xlsx')

# final_analysis = pd.concat([dftotalmarks,passing], axis=1)

# with pd.ExcelWriter('Analysed-Output.xlsx') as writer:  # doctest: +SKIP
#     final_analysis.to_excel(writer, sheet_name='TotalMarks')

# %%
dftotalmarks
# Out:
#      SEAT                                   NAME MICROPROCESSOR-TOT  \
# 1   45062      ACHAREKAR MANAS SANTOSH SHUBHANGI                 64
# 2   45063        ADHANGLE KUNAL RAJENDRA SUREKHA                 44
# 3   45064      AGARWAL SHIVANG DEVENDRA PRATIBHA                 12
# 4   45065   / AKSHANTULU RIDHIMA SURENDRA MALINI                 45
# 5   45066        AMBILPURE SAMEER SURENDRA MEENA                 74
# 6   45067         BAVISKAR VISHAL SHEKHAR CHHAYA                 73
# 7   45068      / BAYAS SIMRAN RAJESHSINGH VARSHA                 55
# 8   45069         BELANEKAR GIRIRAJ GANPAT PRIYA                 66
# 9   45070          BHARATI KOUSHIK PRABIR SHEELA                 47
# 10  45071            BHOGAONKAR AMEY ARUN ASMITA                 75
# 11  45072             BHOIR ABHISHEK ARJUN AMITA                 64
# 12  45073             BHOLE SOHAM PRAMOD MADHURI                  7
# 13  45074         BORKAR SHRUTI HRISHIKESH PRIYA                 25
# 14  45075       / CHAUBAL PRIYANKA SANJAY SONALI                 64
# 15  45076        DANDEKAR HARSHAD HARESH NARMADA                 41
# 16  45077         DEOLEKAR RAHUL RAJESH SANGEETA                 46
# 17  45078            DESAI KATHAN JITESH MANISHA                 56
# 18  45079            / DESAI SALONI NITIN ANJALI                 72
# 19  45080        / DHAGE PRACHI SURESH DAMAYANTI                 71
# 20  45081              DIXIT GOPESH DINESH NEETU                 39
# 21  45082            GAIKWAD ADITYA SANJAY REKHA                 44
# 22  45083                GAIKWAD RAJ ANIL ANJALI                 29
# 23  45084       / GAVASKAR DEVASHRI GIRISH GAURI                 78
# 24  45085        / GHARAT CHARMI RAJESH RAJESHRE                 42
# 25  45086  GHOSH SIDDHARTHA SAMIRENDRA SARMISTHA                 71
# 26  45087           GOPHANE SAHIL SAKHARAM KANTA                 49
# 27  45088              GORE BHAVEN VIKAS BHAVIKA                 77
# 28  45089      GUPTE SHREESHAIL SHAILENDRA SEEMA                 63
# 29  45090            INGLE SHUBHAM DEEPAK VARSHA                 44
# 30  45091       JADHAV HARSHVARDHAN SANJAY MEGHA                 10
# ..    ...                                    ...                ...
# 57  45118         MIRAJKAR ADITYA VINOD VAISHALI                 54
# 58  45119         NAIR ROHAN SREEDHARAN SHAILAJA                 51
# 59  45120     PABHAREKAR NIRANJAN MANOHAR LALITA                 42
# 60  45121              PATEL JASH MAHENDRA VEENA                 60
# 61  45122              PATEL JUNAID ASIF NASEEMA                 67
# 62  45123          PATHAN TALIF ANDALIB NAWSHEEN                 70
# 63  45124          PATIL JIGNESH SANJAY SANGEETA                 46
# 64  45125             PAWAR DEVEN VINOD VISHAKHA                 57
# 65  45126            PAWAR SHUBHAM VASANT KAVITA                 45
# 66  45127           PIMPALE RUNAL RAJENDRA NILAM                 56
# 67  45128     POTDAR PRATHMESH SUBHASH SHUBHANGI                 27
# 68  45129            RAUL MIHIR SHAILESH MADHURI                 55
# 69  45130          SANGHAVI TANISH BHAVESH NEETA                 43
# 70  45131              SAVE VIDIT VIRAJ VISHAKHA                 64
# 71  45132             SENEKAR BOBBY KISHOR NEETA                 43
# 72  45133              SHARMA YUGEEN JANAK SEEMA                 44
# 73  45134             SHETE SHUBHAM SANJAY GEETA                 52
# 74  45135    / SHIRDHANKAR DISHA MOHAN MEENAKSHI                 60
# 75  45136          SHITOLE MAYURESH SURESH SMITA                 44
# 76  45137   / SHIVSHARAN PRIYANKA BASLING AMBIKA                 20
# 77  45138              TANK NEERAJ DEEPAK KOKILA                 60
# 78  45139        TIMBADIA DHAIRYA CHETAN JASMINA                 13
# 79  45140          TIWARI SAGAR SURENDRA SHOBHNA                 11
# 80  45141             VARTAK SANMIT PANKAJ NISHA                 58
# 81  45142      / VARULE JAGRUTI NANDKUMAR SUNITA                 59
# 82  45143        VAYDANDE AJINKYA VILAS SUDHATAI                 40
# 83  45144            WANKHEDE VAIBHAV ASHOK ASHA                 30
# 84  45145             DALVI SAISH MUKUND MANDIRA                 16
# 85  45146         / RAINA ARUNDHATI RAJESH DEEPA                  6
# 86  45147         SHAH MADNI ABDUL SAMAD SHEHNAZ                 21
#
#    DATABASE MANAGEMENT SYSTEM-TOT COMPUTER NETWORK-TOT  \
# 1                              55                   43
# 2                              62                   56
# 3                              66                   43
# 4                              52                   43
# 5                              55                   62
# 6                              75                   71
# 7                              59                   50
# 8                              69                   60
# 9                              62                   51
# 10                             69                   66
# 11                             82                   73
# 12                             60                   41
# 13                             44                   48
# 14                             68                   66
# 15                             58                   52
# 16                             70                   69
# 17                             71                   73
# 18                             80                   66
# 19                             70                   76
# 20                             67                   56
# 21                             63                   58
# 22                             52                   30
# 23                             77                   61
# 24                             76                   44
# 25                             74                   68
# 26                             58                   41
# 27                             77                   64
# 28                             75                   59
# 29                             63                   66
# 30                             46                   40
# ..                            ...                  ...
# 57                             74                   68
# 58                             60                   59
# 59                             66                   41
# 60                             61                   68
# 61                             74                   61
# 62                             79                   67
# 63                             70                   54
# 64                             58                   59
# 65                             68                   56
# 66                             70                   57
# 67                             67                   47
# 68                             77                   55
# 69                             71                   42
# 70                             73                   73
# 71                             67                   43
# 72                             60                   60
# 73                             67                   47
# 74                             75                   55
# 75                             60                   46
# 76                             59                   44
# 77                             70                   57
# 78                             53                   41
# 79                             38                   21
# 80                             72                   64
# 81                             68                   62
# 82                             55                   42
# 83                             64                   48
# 84                             48                   39
# 85                             41                   15
# 86                             45                   20
#
#    THEORY OF COMPUTER SCIENCE-TOT MULTIMEDIA SYSTEM-TOT      TOTAL  SGPI  \
# 1                              48                    47        445   6.3
# 2                              47                    45        443   6.3
# 3                              25                    46        375  4.74
# 4                              55                    20        397  5.33
# 5                              50                    43        479  7.04
# 6                              75                    72        575  8.81
# 7                              40                    55        448  6.44
# 8                              49                    51        501  7.15
# 9                              45                    49        365  3.56
# 10                             64                    62        534  7.89
# 11                             67                    79        582  8.67
# 12                             43                    36        309   3.7
# 13                             42                    35        370  3.56
# 14                             55                    81        462  6.41
# 15                             40                    52        413  5.85
# 16                             61                    48        485  6.37
# 17                             56                    57        507  7.33
# 18                             65                    55        543  8.04
# 19                             49                    54        519  7.81
# 20                             48                    46        380  3.78
# 21                             51                    26        385  4.48
# 22                             40                    33        322  2.15
# 23                             75                    75        581  8.96
# 24                             42                    60        455  6.48
# 25                             53                    59        530   7.7
# 26                             43                    59  422\r\n@2  5.93
# 27                             82                    62        573  8.74
# 28                             63                    52        518  7.59
# 29                             45                    58        479  6.85
# 30                             21                    20        289  2.41
# ..                            ...                   ...        ...   ...
# 57                             54                    70        525  7.63
# 58                             62                    65        483  7.11
# 59                             55                    51        434  6.04
# 60                             50                    48        447   6.7
# 61                             48                    65        499  7.22
# 62                             68                    82        559  8.37
# 63                             40                    64        447  6.44
# 64                             61                    64        491  7.07
# 65                             55                    64        449  6.52
# 66                             54                    59        489  7.04
# 67                             53                    58        443  5.89
# 68                             65                    68        536  7.78
# 69                             66                    51        471   6.7
# 70                             72                    73        565  8.33
# 71                             49                    50        400  5.19
# 72                             59                    62        461   6.7
# 73                             61                    55        477  6.96
# 74                             61                    57        502  7.48
# 75                             46                    52        432  6.22
# 76                             52                    61        431  5.74
# 77                             58                    53        492  7.33
# 78                             39                    30        328  2.85
# 79                             38                    41        287  1.78
# 80                             68                    61        507  7.37
# 81                             56                    50        485  6.96
# 82                             52                    54        426  6.11
# 83                             56                    49        420  5.48
# 84                             56                    43        336  3.52
# 85                             27                    19        242  1.85
# 86                             40                    45        318  3.48
#
#    RESULT
# 1       P
# 2       P
# 3       F
# 4       F
# 5       P
# 6       P
# 7       P
# 8       P
# 9       F
# 10      P
# 11      P
# 12      F
# 13      F
# 14      F
# 15      P
# 16      F
# 17      P
# 18      P
# 19      P
# 20      F
# 21      F
# 22      F
# 23      P
# 24      P
# 25      P
# 26      P
# 27      P
# 28      P
# 29      P
# 30      F
# ..    ...
# 57      P
# 58      P
# 59      P
# 60      P
# 61      P
# 62      P
# 63      P
# 64      P
# 65      P
# 66      P
# 67      F
# 68      P
# 69      P
# 70      P
# 71      F
# 72      P
# 73      P
# 74      P
# 75      P
# 76      F
# 77      P
# 78      F
# 79      F
# 80      P
# 81      P
# 82      P
# 83      F
# 84      F
# 85      F
# 86      F
#
# [86 rows x 10 columns]
