# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
marks = pd.read_excel('TotalMarks.xlsx')

# %%
marks = marks.iloc[:,1:]

# %%
cols = list(marks.columns[2:-3])

# %%
histogram = []
for i in cols:
    x = [len([j for j in marks.loc[:,i] if j <= 50])]
    x.append(len([j for j in marks.loc[:,i] if j > 50 and j <= 60]))
    x.append(len([j for j in marks.loc[:,i] if j > 60]))
    histogram.append(x)

# %%
df1 = [['1. <50',cols[i],histogram[i][0]] for i in range(len(cols))]
df1 = df1 + [['2. 5060',cols[i],histogram[i][1]] for i in range(len(cols))]
df1 = df1 + [['3. 60+',cols[i],histogram[i][2]] for i in range(len(cols))]
df1 = df1 + [['4. Total',cols[i],len(marks.iloc[:,2:i])] for i in range(len(cols))]
df1 = df1 + [['5. Passed',cols[i],sum(marks.iloc[:,2+i].apply(lambda x : int(x) >35))] for i in range(len(cols))]

df1 = pd.DataFrame(df1, columns=[ 'Ranges','Subject', 'No.of Students'])

df1 = df1.pivot( 'Ranges','Subject', 'No.of Students')
df1.columns = [i.split('-')[0] for i in df1.columns]

df1.plot(kind='bar',figsize=(20,10))
plt.xticks(np.arange(5),('Less than 50','Between 50 and 60','Greater than 60','Total Appeared', 'Passed Percentages'),rotation='horizontal')
plt.ylabel('No. of Students',fontsize=20)
plt.xlabel('Subject Wise Distribution',fontsize=20)

plt.savefig('SUB.jpg')

# %%
sgpi = [['Less Than 4', sum(marks['SGPI'].apply(lambda x: float(x)<4))],
       ['Between 4 & 5', sum(marks['SGPI'].apply(lambda x: float(x) > 4 and float(x) <5))],
       ['Between 5 & 6', sum(marks['SGPI'].apply(lambda x: float(x) > 5 and float(x) <6))],
       ['Between 6 & 7', sum(marks['SGPI'].apply(lambda x: float(x) > 6 and float(x) <7))],
       ['Between 7 & 8', sum(marks['SGPI'].apply(lambda x: float(x) > 7 and float(x) <8))],
       ['Between 8 & 9', sum(marks['SGPI'].apply(lambda x: float(x) > 8 and float(x) <9))],
       ['Between 9 & 10', sum(marks['SGPI'].apply(lambda x: float(x) > 9 and float(x) <10))]]
sgpi = pd.DataFrame(sgpi, columns=['Range','No. of Students'])

# %%
ax = sgpi.plot.bar(x='Range', y='No. of Students', rot=0, figsize=(20,10), grid=True)
plt.xlabel('SGPI Statistics', fontsize=20)
plt.ylabel('No. of Students',fontsize=20)
plt.savefig('SGPI.jpg')

# %%
for i in marks.columns[2:-3]:
    subject = [['Less Than 40', sum(marks[i].apply(lambda x: float(x)< 40))],
                ['Between 40 & 50', sum(marks[i].apply(lambda x: float(x) >= 40 and float(x) <50))],
                ['Between 50 & 60', sum(marks[i].apply(lambda x: float(x) >= 50 and float(x) <60))],
                ['Between 60 & 70', sum(marks[i].apply(lambda x: float(x) >= 60 and float(x) <70))],
                ['Between 70 & 80', sum(marks[i].apply(lambda x: float(x) >= 70 and float(x) <80))],
                ['Above 80', sum(marks[i].apply(lambda x: float(x) >= 80))]]
    subject = pd.DataFrame(subject, columns=['Range','No. of Students'])
    ax = subject.plot.bar(x='Range', y='No. of Students', rot=0, figsize=(20,10), grid=True)
    plt.xlabel(i.split("-")[0], fontsize=20)
    plt.ylabel('No. of Students',fontsize=20)
    plt.savefig(i+'.jpg')

# %%
marks
# Out:
#      SEAT                                        NAME  MICROPROCESSOR-TOT  \
# 0   45001              AMBILPURE SAGAR SURENDRA MEENA                  62
# 1   45002              / ANGNE HEMALI KISHORE KAUMUDI                  71
# 2   45003          ATKARI ADITYA CHANDRAKANT SHARMILA                  80
# 3   45004          CHAUDHARI RUTURAJ NARENDRA MANISHA                  42
# 4   45005                  CHAVAN ADITYA RAMESH JYOTI                  65
# 5   45006                 CHHAPRA UZAIR ASIF NAUSHEEN                  65
# 6   45007         DHARGALKAR NISHANT SHAILESH MANISHA                  55
# 7   45008                   / DUDHAL SHWETA RAJU USHA                  78
# 8   45009                 GAWDE VARNESH PRASHANT ULKA                  49
# 9   45010                 GHOJARIA SAAD IMTIAZ RUMANA                  47
# 10  45011            JADEJA HARPALSINH TANUBHA TARABA                  64
# 11  45012                JANGID MUKUL DAYANAND LALITA                  32
# 12  45013                  KASALE SANKALP NARESH NEHA                  45
# 13  45014            KHAN IMRAN KHURSHID ALAM SHABANA                  45
# 14  45015                  KOLEKAR AAKASH ANIL SAVITA                  87
# 15  45016              MORYE MANDAR VISHWANATH RUPALI                  44
# 16  45017          / MUTHA AKANKSHA AMARCHAND SANGITA                  62
# 17  45018                  NAIK AKSHAY HEMANT HEMANGI                  57
# 18  45019                / PAGAR RIDDHI KISAN SANDHYA                  72
# 19  45020               / PANDA DEEPALI SURJA MINNOTI                  65
# 20  45021             PANDEY SHREYAS SURENDRA MADHURI                  64
# 21  45022  PASI PIYUSH SINGH UMESH CHANDRA JWALAMUKHI                  69
# 22  45023                 PATEL DARSHAN RANJIT BHAVNA                  53
# 23  45024               / PATEL DISHA DHARMESH AMPARA                  28
# 24  45025         / PATEL KANISHKA ALPESHBHAI MITABEN                  79
# 25  45026               PATHAK VAIBHAV SUSHIL KANCHAN                  55
# 26  45027               PATIL BHUSHAN BHAURAO VANDANA                  59
# 27  45028               PEDNEKAR MIHIR SANDEEP TRUPTI                  52
# 28  45029            PUSEGAONKAR SAMEER SATISH SUSHMA                  56
# 29  45030              / RAJE GAYATRI SURYAKANT ANITA                  75
# ..    ...                                         ...                 ...
# 31  45032                RATH BUDDHADITYA MITALI RATH                  36
# 32  45033                RAUT PRANAV VIRENDRA PRERENA                  57
# 33  45034              / RAWAT SHIVANI SURENDER KANTI                  69
# 41                              67                    67
# 42                              74                    74
# 43                              67                    66
# 44                              77                    72
# 45                              73                    64
# 46                              60                    55
# 47                              72                    60
# 48                              72                    73
# 49                              62                    61
# 50                              59                    64
# 51                              67                    63
# 52                              68                    62
# 53                              44                    39
# 54                              60                    61
# 55                              65                    54
# 56                              68                    68
# 57                              76                    77
# 58                              70                    70
# 59                              72                    64
# 60                              67                    76
#
#     THEORY OF COMPUTER SCIENCE-TOT  ADVANCE ALGORITHM-TOT  TOTAL  SGPI RESULT
# 0                               68                     77    534  7.85      P
# 1                               87                     85    605  9.26      P
# 2                               76                     91    620  9.41      P
# 3                               44                     67    449  6.26      P
# 4                               60                     78    546  8.26      P
# 5                               62                     72    547  7.96      P
# 6                               72                     91    577  8.67      P
# 7                               75                     86    599  9.41      P
# 8                               63                     78    541  7.93      P
# 9                               49                     60    480  6.93      P
# 10                              70                     72    531  7.85      P
# 11                              50                     69    436  5.85      F
# 12                              57                     66    491  7.04      P
# 13                              68                     79    520  7.59      P
# 14                              75                     86    625  9.56      P
# 15                              63                     67    502  7.11      P
# 16                              59                     72    519  7.52      P
# 17                              52                     87    540  7.93      P
# 18                              71                     82    580  8.81      P
# 19                              71                     92    592  8.67      P
# 20                              61                     73    541  8.19      P
# 21                              79                     91    610  8.96      P
# 22                              57                     87    536  7.85      P
# 23                              56                     71    491  6.70      F
# 24                              67                     87    595  8.89      P
# 25                              67                     72    526  7.70      P
# 26                              60                     72    490  7.11      P
# 27                              55                     81    460  7.04      P
# 28                              50                     76    495  7.37      P
# 29                              69                     91    595  8.67      P
# ..                             ...                    ...    ...   ...    ...
# 31                              35                     55    368  4.11      F
# 32                              66                     65    501  7.30      P
# 33                              72                     74    562  8.19      P
# 34                              56                     51    417  6.15      P
# 35                               9                     66    390  4.93      F
# 36                              66                     86    545  8.04      P
# 37                              66                     83    548  8.30      P
# 38                              73                     86    560  8.30      P
# 39                              59                     81    543  8.04      P
# 40                              64                     77    546  7.93      P
# 41                              69                     87    577  8.33      P
# 42                              74                     87    613  9.11      P
# 43                              55                     75    503  7.33      P
# 44                              61                     71    546  8.19      P
# 45                              56                     74    522  7.67      P
# 46                              43                     53    445  6.26      P
# 47                              56                     78    559  8.22      P
# 48                              66                     84    593  8.89      P
# 49                              57                     72    497  7.26      P
# 50                              42                     68    458  6.44      P
# 51                              64                     79    564  8.22      P
# 52                              60                     86    549  8.19      P
# 53                              27                     49    338  3.33      F
# 54                              68                     87    549  8.30      P
# 55                              50                     76    498  7.37      P
# 56                              65                     76    541  7.93      P
# 57                              71                     90    594  9.15      P
# 58                              55                     83    551  8.19      P
# 59                              53                     86    541  8.07      P
# 60                              65                     85    577  8.74      P
#
# [61 rows x 10 columns]
